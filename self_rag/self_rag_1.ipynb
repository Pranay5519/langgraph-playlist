# %% [markdown]
# ## Self-Rag-1

# %%
from typing import List, TypedDict, Literal
from pydantic import BaseModel, Field
import time
from langchain_huggingface import HuggingFaceEmbeddings

from langchain_community.vectorstores import FAISS
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_core.prompts import ChatPromptTemplate

from langgraph.graph import StateGraph, START, END
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
def load_transcript(url: str):
    pattern = r'(?:v=|\/)([0-9A-Za-z_-]{11})'
    match = re.search(pattern, url)

    if not match:
        return None

    video_id = match.group(1)

    try:
        transcript = YouTubeTranscriptApi().fetch(
            video_id,
            languages=["en", "hi"]
        )

        snippets = transcript.snippets

        # Create a single Document with timestamps included
        full_text = " ".join(
            [f"{item.text} ({item.start})" for item in snippets]
        )

        return [Document(page_content=full_text)]

    except Exception as e:
        print(f"❌ Error fetching transcript: {e}")
        return None


# ---------------------------------------
# 2️⃣ Load docs
# ---------------------------------------
docs = load_transcript(
    "https://www.youtube.com/watch?v=OLQRAMZi--c&t=299s"
)

if docs is None:
    raise ValueError("Transcript could not be loaded.")

# %%
docs
# Out:
# [Document(metadata={}, page_content="welcome to huberman lab Essentials where (0.199) we revisit past episodes for the most (2.52) potent and actionable science-based (4.92) tools for mental health physical health (6.919) and (9.32) performance I'm Andrew huberman and I'm (10.84) a professor of neurobiology and (13.16) Opthalmology at Stanford school of (15.0) medicine today we're going to talk about (16.88) an extremely important topic that's (18.76) Central to our daily life and that's (20.96) motivation we're going to talk about (23.359) pleasure and reward what underlies our (25.4) sense of pleasure or reward we're going (27.96) to talk about addictions as well we're (30.199) going to talk about the neurochemistry (32.8) of drive and mindset but for now let's (35.239) just talk about the Neuroscience of (38.559) motivation and reward of Pleasure and (40.039) Pain because those are Central to what (42.879) we think of as emotions whether or not (45.32) we feel good whether or not we feel (46.92) we're on track in life whether or not we (48.32) feel we're falling behind so motivation (49.92) is fundamental to our daily life it's (53.44) what allows us to get out of bed in the (56.0) morning it's what allows us to pursue (57.52) longterm goals or short-term goals (59.559) motivation and the chemistry of (62.399) motivation is tightly wound in with the (64.6) neurochemistry of movement in fact the (68.6) same single molecule dopamine is (71.479) responsible for our sense of motivation (74.6) and for movement it's a fascinating (77.56) molecule and it lies at the center of so (80.72) many great things in life and it lies at (83.799) the center of so many terrible aspects (86.439) of Life namely addiction and certain (88.479) forms of mental disease so if ever there (90.28) was a double-edged blade in the world of (92.88) Neuroscience it's dopamine there's a (96.079) fundamental relationship between (98.799) dopamine released in your brain and your (100.439) desire to exert effort and you can (102.72) actually control the schedule of (105.24) dopamine release but it requires the (107.28) appropriate knowledge this is one of (109.479) those cases where understanding the way (111.2) the dopamine system works will allow you (113.24) to leverage it to your benefit let's get (114.84) a few basic facts on the table dopamine (116.96) was discovered in the late 1950s and it (120.64) was discovered as the precursor meaning (123.399) the thing from which epinephrine or (126.32) adrenaline is made epinephrine is the (128.959) same thing as adrenaline except in the (131.44) brain we call it epinephrine (133.28) epinephrine allows us to get into action (135.64) it stimulates changes in the blood (139.239) vessels in the heart in the organs and (141.0) tissues of the body that bias us for (142.72) movement dopamine was initially thought (145.28) to be just the building block for (147.56) epinephrine (149.319) however dopamine does a lot of things on (150.44) its own it's not always converted to (152.239) epinephrine dopamine is released from (154.76) several sites in the brain and body but (157.12) perhaps the most important one for (159.519) today's discussion about motivation and (160.879) reward is something that sometimes just (162.76) called the reward pathway for the (164.76) afficianados it's sometimes called the (167.159) misol limic reward pathway but it's (168.8) fundamentally important to your desire (171.92) to engage in action and it's (174.64) fundamentally important for people (177.48) getting addicted to substances or (179.959) behaviors so how does this work well (182.159) you've got a structure in the Deep part (184.799) of your brain called the VTA the VTA or (186.76) vental tegmental area contains neurons (189.319) that send what we call axons little (192.08) wires that spit out dopamine at a (194.599) different structure called the nucleus (197.599) accumbent and those two structures VTA (199.2) and nucleus accumbent form ...

# %%
chunks = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=150
).split_documents(docs)

# 2️⃣ Create embeddings
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2",
    model_kwargs={"device": "cpu"}
)

# 3️⃣ Create vector store
vector_store = FAISS.from_documents(chunks, embeddings)

# 4️⃣ Create retriever
retriever = vector_store.as_retriever(search_kwargs={"k": 4})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\prana\Desktop\VS_CODE\Langraph\myvenv\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:68, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      67 try:
# ---> 68     import sentence_transformers  # type: ignore[import]
#      69 except ImportError as exc:
#
# ModuleNotFoundError: No module named 'sentence_transformers'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 7
#       1 chunks = RecursiveCharacterTextSplitter(
#       2     chunk_size=1000,
#       3     chunk_overlap=150
#       4 ).split_documents(docs)
#       6 # 2️⃣ Create embeddings
# ----> 7 embeddings = HuggingFaceEmbeddings(
#       8     model_name="sentence-transformers/all-MiniLM-L6-v2",
#       9     model_kwargs={"device": "cpu"}
#      10 )
#      12 # 3️⃣ Create vector store
#      13 vector_store = FAISS.from_documents(chunks, embeddings)
#
# File c:\Users\prana\Desktop\VS_CODE\Langraph\myvenv\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:74, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      69 except ImportError as exc:
#      70     msg = (
#      71         "Could not import sentence_transformers python package. "
#      72         "Please install it with `pip install sentence-transformers`."
#      73     )
# ---> 74     raise ImportError(msg) from exc
#      76 if self.model_kwargs.get("backend", "torch") == "ipex":
#      77     if not is_optimum_intel_available() or not is_ipex_available():
#
# ImportError: Could not import sentence_transformers python package. Please install it with `pip install sentence-transformers`.

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.7)

# %%
# --------------------------------------------------
# Graph State
# --------------------------------------------------
class State(TypedDict):
    question: str
    need_retrieval: bool

    docs: List[Document]

    answer: str

# %%
class RetrieveDecision(BaseModel):
    should_retrieve: bool = Field(
        ...,
        description="True if external documents are needed to answer reliably, else False."
    )

decide_retrieval_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You decide whether retrieval is needed.\n"
            "Return JSON that matches this schema:\n"
            "{{'should_retrieve': boolean}}\n\n"
            "Guidelines:\n"
            "- should_retrieve=True if answering requires specific facts, citations, or info likely not in the model.\n"
            "- should_retrieve=False for general explanations, definitions, or reasoning that doesn't need sources.\n"
            "- If unsure, choose True."
        ),
        ("human", "Question: {question}"),
    ]
)


# IMPORTANT: no `.content` for structured output
should_retrieve_llm = llm.with_structured_output(RetrieveDecision)

def decide_retrieval(state: "State"):
    decision: RetrieveDecision = should_retrieve_llm.invoke(
        decide_retrieval_prompt.format_messages(question=state["question"])
    )
    return {"need_retrieval": decision.should_retrieve}

# %%
direct_generation_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "Answer the question using only your general knowledge.\n"
            "Do NOT assume access to external documents.\n"
            "If you are unsure or the answer requires specific sources, say:\n"
            "'I don't know based on my general knowledge.'"
        ),
        ("human", "{question}"),
    ]
)


def generate_direct(state: State):
    out = llm.invoke(
        direct_generation_prompt.format_messages(
            question=state["question"]
        )
    )
    return {
        "answer": out.content
    }

# %%
def retrieve(state: State):
    return {"docs": retriever.invoke(state["question"])}

# %%
def route_after_decide(state: State) -> Literal["generate_direct", "retrieve"]:
    if state["need_retrieval"]:
        return "retrieve"
    return "generate_direct"

# %%
g = StateGraph(State)

# --------------------
# Nodes
# --------------------
g.add_node("decide_retrieval", decide_retrieval)
g.add_node("generate_direct", generate_direct)
g.add_node("retrieve", retrieve)

# --------------------
# Edges
# --------------------
g.add_edge(START, "decide_retrieval")

g.add_conditional_edges(
    "decide_retrieval",
    route_after_decide,
    {
        "generate_direct": "generate_direct",
        "retrieve": "retrieve",
    },
)

g.add_edge("generate_direct", END)
g.add_edge("retrieve", END)  # temporary END for retrieval path

app = g.compile()
app

# %%
result = app.invoke(
    {
        "question": "What is Machine Learning",
        "need_retrieval": False,
        "docs": [],
        "answer": "",
    }
)

print(result["answer"])
