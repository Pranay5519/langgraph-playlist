# %%
from langgraph.graph import StateGraph , START  , END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv  import load_dotenv

load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

# %%
class LLMState(TypedDict):

    question : str
    answer : str

# %%
def llm_qa(state = LLMState) -> LLMState:
    # extract question from state
    question = state['question']
    prompt = f' answer the following {question}'
    answer = model.invoke(prompt).content
    state['answer'] = answer
    return state

# %%
# create graph 

graph = StateGraph(LLMState)

graph.add_node('llm_QA' , llm_qa)

graph.add_edge(START , 'llm_QA')
graph.add_edge('llm_QA' , END)

workflow= graph.compile()

# %%
initial_state =  {'question' : 'what is langchain'}
result = workflow.invoke(initial_state)
result
# Out:
# {'question': 'what is langchain',
#  'answer': '**LangChain is an open-source framework designed to simplify the development of applications powered by Large Language Models (LLMs).**\n\nThink of LLMs as incredibly powerful but raw engines. LangChain provides the "chassis," "steering wheel," "dashboard," and all the other components that turn that raw engine into a functional, intelligent vehicle capable of performing complex tasks.\n\nIn essence, LangChain helps you:\n\n1.  **Connect LLMs with external data:** LLMs are trained on vast amounts of data, but their knowledge is static. LangChain allows them to access up-to-date information from the internet, databases, documents, etc.\n2.  **Connect LLMs with external computation:** LLMs are great at language, but not at complex math or executing code. LangChain enables them to use tools like calculators, APIs, or custom scripts.\n3.  **Orchestrate complex workflows:** Instead of just a single prompt-response, LangChain allows you to chain together multiple LLM calls, tool usages, and data retrievals to achieve more sophisticated goals.\n\n---\n\n### Key Concepts and Components of LangChain:\n\nLangChain is built around several core modules that facilitate this orchestration:\n\n1.  **Models:**\n    *   **LLMs:** Integrations with various large language models (e.g., OpenAI\'s GPT series, Google\'s PaLM/Gemini, Hugging Face models, Anthropic\'s Claude).\n    *   **Chat Models:** Specifically designed for conversational interfaces, handling message histories.\n    *   **Embeddings:** Tools for converting text into numerical vectors, crucial for semantic search and retrieval.\n\n2.  **Prompts:**\n    *   **Prompt Templates:** Standardized and reusable ways to construct prompts for LLMs, including input variables and formatting.\n    *   **Output Parsers:** Tools to structure the LLM\'s text output into more usable formats (e.g., JSON, lists).\n\n3.  **Chains:**\n    *   Sequences of calls, allowing you to combine LLMs with other components (e.g., a chain that takes user input, formats it into a prompt, sends it to an LLM, and then parses the output).\n    *   Examples: `LLMChain`, `SequentialChain`, `RetrievalQAChain`.\n\n4.  **Agents:**\n    *   LLMs that can *reason* about what actions to take and *execute* those actions using a set of tools. They decide the sequence of steps dynamically.\n    *   This is where the LLM acts as a "brain" that observes, thinks, and acts.\n\n5.  **Tools:**\n    *   Functions that agents can call to interact with the outside world (e.g., Google Search, a calculator, a database query, a custom API call).\n\n6.  **Memory:**\n    *   Mechanisms to persist state between calls of a chain or agent. This is essential for conversational applications where the LLM needs to remember past interactions.\n    *   Examples: `ConversationBufferMemory`, `ConversationSummaryMemory`.\n\n7.  **Retrieval:**\n    *   Components for fetching relevant data from external sources. This is crucial for **Retrieval Augmented Generation (RAG)**, where an LLM\'s response is grounded in specific, up-to-date information.\n    *   **Document Loaders:** To load data from various sources (PDFs, websites, databases).\n    *   **Text Splitters:** To break down large documents into smaller, manageable chunks.\n    *   **Vector Stores:** Databases that store text embeddings, enabling semantic search.\n\n---\n\n### Why Use LangChain?\n\n*   **Accelerated Development:** Provides pre-built components and abstractions, allowing developers to build complex LLM applications much faster.\n*   **Modularity and Reusability:** Components are designed to be interchangeable and reusable across different applications.\n*   **Context Awareness:** Enables LLMs to access and utilize external, up-to-date information, overcoming their knowledge cut-off.\n*   **Action Capabilities:** Allows LLMs to perform actions in the real world through tools, moving beyond just generating text.\n*   **Statefulness:** Adds memory to LLM interactions, makin ...

# %%
type(result)
# Out:
# dict
