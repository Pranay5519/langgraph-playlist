# %% [markdown]
# # Agent 1

# %% [markdown]
# ## imports and pydanctic models

# %%
import sys
import subprocess
import uuid
import re
from pathlib import Path
from typing import TypedDict
from dotenv import load_dotenv
from langgraph.graph import StateGraph, END
from langchain_core.output_parsers import PydanticOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage
from pydantic import BaseModel, Field
from typing import Optional
load_dotenv()
# Out:
# True

# %%
class AgentState(TypedDict):
    user_query: str
    generated_code: str
    scene_name : str
    execution_output: dict
    final_answer: str
    video_path: str
    retry_count: int
    max_retries: int
    error_history: list  # Track all errors
    error_fixed : str


class CodeOutput(BaseModel):
    code: str
    fix_explanation: Optional[str] = Field(
        default=None,
        description="Explanation of how the error was fixed"
    )
    
    
class ExpandedPrompt(BaseModel):
    expanded_prompt: str

# %%
# -----------------------------
# LLM (Gemini 2.5 Flash)
# -----------------------------
from langchain_ollama import ChatOllama
llm = ChatOllama(
    model="deepseek-r1:8b",
    temperature=0.7
)
google_llm = ChatGoogleGenerativeAI(model = 'gemini-2.5-flash')

# %%
llm
# Out:
# ChatOllama(model='deepseek-r1:8b', temperature=0.7)

# %% [markdown]
# ## prompt_expander_node

# %%
def prompt_expaner_node(scene_name):
        # ✅ Store system prompt separately
    system_prompt = f"""
    You are a Manim scene planner. Your job is to take a short user request and
    expand it into a detailed, technical Manim scene description that another AI
    will use to write Python code.

    Scene class name: {scene_name}

    Think like a Manim developer planning a scene. Your expanded prompt MUST include:
    1. OBJECTS — What Mobjects to create (Circle, Text, Cylinder, etc.) with exact colors using built-in constants (RED, BLUE, GREEN, DARK_BROWN etc.) or ManimColor("#RRGGBB") for custom colors
    2. POSITIONS — Where each object goes using move_to(), next_to(), to_edge() — NEVER use shift() for absolute positions
    3. ANIMATION ORDER — Step by step what happens and in what sequence (Create, Write, FadeIn, Transform, etc.)
    4. TIMING — How long each animation runs, where to self.wait()
    5. TEXT — Any labels or titles to display, their font sizes
    6. CAMERA — If 3D, what camera angle (phi, theta in degrees)

    ================================================================================
    SCREEN BOUNDARY RULES — STRICT
    ================================================================================
    The Manim screen is 16:9 ratio. Safe coordinate boundaries are:
    X axis: -6.5 to +6.5 (horizontal)
    Y axis: -3.5 to +3.5 (vertical)

    - ALL objects, text, and shapes MUST stay within these boundaries
    - Text font size must be 28 or smaller for body text, 40 max for titles
    - If placing multiple text lines, stack them vertically with 0.6–0.8 unit gaps
    - NEVER place anything beyond x=±6 or y=±3.5 — it will go off screen
    - Long text MUST be broken into shorter lines using line breaks or multiple Text objects
    - For subtitles or captions, always place at y=-3.0 (bottom) and keep font_size <= 24

    ================================================================================
    TIMING & PACING RULES
    ================================================================================
    - Keep animations snappy — default run_time=1.0 unless something needs emphasis
    - self.wait() should be 0.5 to 1.5 seconds max between steps
    - Do NOT use self.wait(3) or longer unless it is the final hold at the end
    - Total scene length should aim for 30–60 seconds, not longer
    - Voiceover text should be SHORT sentences — max 12 words per voiceover block
    - Each voiceover block should match exactly ONE visual action (one play call)

    ================================================================================
    TEXT & OVERLAP RULES
    ================================================================================
    - NEVER display two Text objects at the same Y position — they will overlap
    - Before adding new text, always FadeOut or remove the previous text first
    - Use VGroup to group related text and manage it together
    - Titles go at y=+3.0 (top), body text at y=0 (center), captions at y=-3.0 (bottom)
    - NEVER use Write() and FadeIn() on two different texts at the same time
    unless they are at clearly different Y positions (at least 0.8 units apart)
    - If showing a list of points, show them one at a time — not all at once

    ================================================================================
    ML / DL / DATA VISUALIZATION RULES
    ================================================================================
    - Use MAXIMUM 5 data points on any graph or chart — no cluttered plots
    - For neural networks: show maximum 3 layers, maximum 4 nodes per layer
    - Label axes clearly but keep axis labels short (1–3 words)
    - For loss curves: use 4–6 points only, smooth curve shape
    - For datasets: show 3–5 example points only — not a full scatter plot
    - Prefer simple NumberPlane or Axes with minimal gridlines
    - Avoid 3D graphs for ML concepts — use 2D always unless specifically asked
    - Color-code different data classes with clearly distinct colors (RED vs BLUE, never similar shades)
    - Always add a short Text label to explain what the graph shows, placed at top

    ================================================================================
    COLOR RULES
    ================================================================================
    When describing colors, always specify the hex code in parentheses.
    Example: "brown (#8B4513)", "forest green (#228B22)"
    Use built-in constants when possible: RED, BLUE, GREEN, YELLOW, WHITE, BLACK,
    ORANGE, PURPLE, PINK, GREY, TEAL, GOLD, MAROON

    ================================================================================
    POSITION RULES
    ================================================================================
    When describing positions, always say:
    "positioned at X units left/right, Y units up/down from center"
    Use move_to(), next_to(), to_edge() — NEVER shift() for absolute positions

    ================================================================================
    ANIMATION LANGUAGE
    ================================================================================
    When describing animations, use plain English order:
    "first appear, then move right, then fade out"
    Always state: object name → animation type → direction/target → timing

    Output a precise, technical, step-by-step scene script — not a story.
    Be specific with Manim class names and method names.

    {{format_instructions}}
    """
    return system_prompt

# %%
def prompt_expander_node(state: AgentState) -> dict:

    scene_name = state["scene_name"]
    user_query = state["user_query"]

    parser = PydanticOutputParser(pydantic_object=ExpandedPrompt)


    system_prompt = prompt_expaner_node(scene_name)
    prompt = ChatPromptTemplate.from_messages([
        ("system", system_prompt),
        ("human", "{user_query}")
    ])

    prompt = prompt.partial(
        format_instructions=parser.get_format_instructions()
    )

    chain = prompt | llm | parser

    response = chain.invoke({
        "user_query": user_query
    })

    return {
        **state,
        "user_query": response.expanded_prompt
    }

# %% [markdown]
# ## Node 2 – generate python code

# %%
import os

def load_system_prompt() -> str:
    prompt_path = r"C:\Users\prana\Desktop\VS_CODE\Langraph\manim_agent\manim_agent_system_prompt_v2.txt"
    with open(prompt_path, "r", encoding="utf-8") as f:
        return f.read()
    
load_system_prompt()
# Out:
# '================================================================================\nMANIM AGENT SYSTEM PROMPT — Manim Community v0.19.x\nFor use with Gemini 2.5 Flash or any LLM with outdated Manim knowledge\n================================================================================\n\nYou are an expert Manim (Manim Community Edition) animation developer writing\nPython code for Manim v0.19.x. Your training data may reflect older versions\n(v0.17 or earlier). This prompt contains all breaking changes from v0.17 to\nv0.19. Treat these rules as ABSOLUTE — they override anything you learned\nduring training.\n\n================================================================================\nSECTION 1 — KNOWN ERRORS YOU MUST NEVER CAUSE\n================================================================================\n\nERROR 1 — Voiceover AttributeError (CRITICAL):\n  BAD:  AttributeError: \'MyScene\' object has no attribute \'set_service\'\n  CAUSE: Using wrong method name for voiceover.\n  FIX:  The correct method is ALWAYS self.set_speech_service(), NOT self.set_service()\n\n  CORRECT voiceover pattern (memorize this exactly):\n  -------------------------------------------------------\n  from manim import *\n  from manim_voiceover import VoiceoverScene\n  from manim_voiceover.services.gtts import GTTSService\n\n  class MyScene(VoiceoverScene):\n      def construct(self):\n          self.set_speech_service(GTTSService())   # <-- CORRECT\n          with self.voiceover(text="Hello world.") as tracker:\n              self.play(Create(Circle()), run_time=tracker.duration)\n  -------------------------------------------------------\n  NEVER write: self.set_service(...)\n  NEVER write: from manim_voiceover import GTTSService  (wrong import path)\n  ALWAYS write: from manim_voiceover.services.gtts import GTTSService\n\n================================================================================\nSECTION 2 — COLOR RULES (v0.18+ ManimColor System)\n================================================================================\n\nRULE: Always use BUILT-IN color constants when they exist.\n      Only use ManimColor("#RRGGBB") for custom colors not in the list below.\n\nAVAILABLE BUILT-IN COLOR CONSTANTS (use these directly, no ManimColor needed):\n  RED, BLUE, GREEN, YELLOW, WHITE, BLACK, ORANGE, PURPLE, PINK,\n  GREY, LIGHT_GREY, DARK_GREY, TEAL, MAROON, GOLD,\n  RED_A, RED_B, RED_C, RED_D, RED_E,\n  BLUE_A, BLUE_B, BLUE_C, BLUE_D, BLUE_E,\n  GREEN_A, GREEN_B, GREEN_C, GREEN_D, GREEN_E,\n  YELLOW_A, YELLOW_B, YELLOW_C, YELLOW_D, YELLOW_E,\n  TEAL_A, TEAL_B, TEAL_C, TEAL_D, TEAL_E,\n  PURPLE_A, PURPLE_B, PURPLE_C, PURPLE_D, PURPLE_E,\n  GOLD_A, GOLD_B, GOLD_C, GOLD_D, GOLD_E,\n  MAROON_A, MAROON_B, MAROON_C, MAROON_D, MAROON_E,\n  GREY_A, GREY_B, GREY_C, GREY_D, GREY_E,\n  LIGHTER_GREY, LIGHT_GREY, GREY, DARK_GREY, DARKER_GREY,\n  LIGHT_BROWN, DARK_BROWN,\n  LIGHT_PINK,\n  PURE_RED, PURE_GREEN, PURE_BLUE\n\nFOR CUSTOM COLORS (hex values not in the list above):\n  color=ManimColor("#8B4513")   # brown / saddle brown\n  color=ManimColor("#228B22")   # forest green\n  color=ManimColor("#FFD700")   # custom gold tone\n\nEXAMPLES:\n  Circle(color=RED)                          # CORRECT - built-in\n  Square(color=ManimColor("#8B4513"))        # CORRECT - custom hex\n  trunk = Cylinder(radius=0.2, height=3, color=ManimColor("#8B4513"))  # CORRECT\n\n  Circle(color=colour.Color("red"))          # WRONG - colour lib removed in v0.18\n  Circle(color="#FF0000")                    # WRONG - pass ManimColor, not raw string\n\nv0.18 COLOR CHANGE: The `colour` Python library was REMOVED. The old\n`colour.Color(...)` usage no longer works. Everything must use ManimColor or\nbuilt-in constants.\n\n================================================================================\nSECTION 3 — POSITIONING RULES\n================================================================================\n\nRULE: NEVER use .shift() to place objects at absolute  ...

# %%
def code_generator_node(state: AgentState):
    scene_name = state["scene_name"]
    system_prompt = load_system_prompt()

    prompt = f"""
{system_prompt}

================================================================================
TASK
================================================================================
You are a Python code generator for Manim animations.

STRICT RULES:
- The class name MUST be exactly: {scene_name}
- Write ONLY valid Python code
- Do not add explanations
- Do not add markdown
- Import all necessary modules

User request:
{state["user_query"]}
"""
    structured_llm = google_llm.with_structured_output(CodeOutput)
    response = structured_llm.invoke([HumanMessage(content=prompt)])

    return {
        **state,
        "generated_code": response.code,
        "retry_count": 0,
        "max_retries": 3,
        "error_history": []
    }

# %% [markdown]
# ## Node 3: Code fixer node

# %%
def code_fixer_node(state: AgentState):
    """Fix code based on error feedback"""

    if state["execution_output"]["returncode"] != 0:

        last_error = state["execution_output"].get("stderr", "")
        previous_code = state["generated_code"]

        prompt = f"""
You are a python code debugger.

The following Manim code has an ERROR:

{previous_code}

ERROR:
{last_error}

Previous errors fixed:
{chr(10).join(state["error_history"][-3:]) if state["error_history"] else "None"}

Fix the code by:
1. Adding missing imports
2. Fixing undefined variables/constants
3. Correcting syntax errors
4. Ensuring all Manim constants are properly imported

Return ONLY valid corrected python code.
"""

        structured_llm = google_llm.with_structured_output(CodeOutput)
        response = structured_llm.invoke(prompt)

        new_error_history = state["error_history"] + [last_error]

        return {
            **state,
            "generated_code": response.code,
            "retry_count": state["retry_count"] + 1,
            "error_history": new_error_history,
            "error_fixed": response.fix_explanation
        }

    return state

# %% [markdown]
# ## helper functions

# %%
# -----------------------------
# helpers for runner
# -----------------------------

def save_code_to_file(code: str, state: AgentState) -> Path:
    "save code to tmp file"
    path = Path("tmp")
    path.mkdir(exist_ok=True)
    scene_name = state['scene_name']
    file_path = path / f"{state['scene_name']}.py"
    file_path.write_text(code, encoding="utf-8")

    return file_path

def extract_manim_scene(code: str) -> str | None:
    pattern = r"class\s+(\w+)\s*\([^)]*Scene[^)]*\)\s*:"
    match = re.search(pattern, code)
    if match:
        return match.group(1)
    return None

def find_generated_mp4() -> Path | None:
    """Find the most recently generated MP4 file in media/videos."""
    media_path = Path("media/videos")
    if not media_path.exists():
        return None
    
    mp4_files = list(media_path.rglob("*.mp4"))
    if not mp4_files:
        return None
    
    return max(mp4_files, key=lambda p: p.stat().st_mtime)

from datetime import datetime
from pathlib import Path
import re


def save_error_log(state: dict, run_output: dict):
    """
    Append only:
    - File + line number
    - Exact line of code where error occurred
    - Final exception line
    - LLM fix explanation (if available)
    """

    log_path = Path("error_log.txt")
    stderr = run_output.get("stderr", "")

    if not stderr:
        return

    # Extract the actual error code line (starts with "> ")
    code_line_match = re.search(r">\s*\d+\s*│.*", stderr)
    code_line = code_line_match.group(0) if code_line_match else "Code line not found"

    # Clean weird box characters
    code_line = re.sub(r"[│┌└─]+", "", code_line).strip()

    # Extract final exception line (last non-empty line)
    lines = [line.strip() for line in stderr.splitlines() if line.strip()]
    final_error_line = lines[-1] if lines else "Unknown error"

    # Extract file + line number
    file_line_match = re.search(r"(.*\.py:\d+)", stderr)
    file_line_info = file_line_match.group(1) if file_line_match else "Unknown location"

    # Get fix explanation from state (if exists)
    fix_explanation = state.get("error_fixed")

    with log_path.open("a", encoding="utf-8") as f:
        f.write("\n========================================\n")
        f.write(f"Timestamp: {datetime.now()}\n")
        f.write(f"Scene: {state.get('scene_name', 'Unknown')}\n")
        f.write(f"{file_line_info}\n")
        f.write(f"{code_line}\n")
        f.write(f"{final_error_line}\n")

        # ✅ Append LLM explanation if available
        if fix_explanation:
            f.write(f"fix: {fix_explanation.strip()}\n")

    return log_path




def run_manim_file(path: Path, scene_name: str, state: AgentState):
    try:
        result = subprocess.run(
            [
                sys.executable,
                "-m",
                "manim",
                "-pql",
                str(path),
                scene_name
            ],
            capture_output=True,
            text=True,
            encoding="utf-8",
            errors="ignore",
            timeout=120
        )

        video_path = None
        if result.returncode == 0:
            video_path = find_generated_mp4()
        else:
            # 🔥 Save error log automatically
            save_error_log(state, {
                "stderr": result.stderr,
                "returncode": result.returncode
            })

        return {
            "stdout": result.stdout,
            "stderr": result.stderr,
            "returncode": result.returncode,
            "video_path": str(video_path) if video_path else None
        }

    except subprocess.TimeoutExpired:
        timeout_output = {
            "stderr": "Manim rendering timed out",
            "returncode": -1
        }

        save_error_log(state, timeout_output)

        return {
            "stdout": "",
            "stderr": timeout_output["stderr"],
            "returncode": -1,
            "video_path": None
        }

# %% [markdown]
# ## Node 4: Code Runner

# %%
# -------------------------------------------------
# Node 3 – Code Runner
# -------------------------------------------------

def code_runner_node(state):
    code = state["generated_code"]
    path = save_code_to_file(code , state=state)

    scene_name = state['scene_name']

    if scene_name is not None:
        output = run_manim_file(path, scene_name , state)
    else:
        output = {
            "stdout": "",
            "stderr": "No Scene class found in generated code",
            "returncode": -1,
            "video_path": None
        }

    return {
        **state,
        "execution_output": output,
        "video_path": output.get("video_path", "")
    }

# %%
# -----------------------------
# Node 4 – Check if needs retry
# -----------------------------

def should_retry(state: AgentState) -> str:
    """Decide if we should retry or finish"""
    
    output = state["execution_output"]
    
    # Success case
    if output["returncode"] == 0:
        return "final_answer"
    
    # Failed but can retry
    if state["retry_count"] < state["max_retries"]:
        print(f"\n⚠️  Error detected. Retry {state['retry_count'] + 1}/{state['max_retries']}")
        return "code_fixer"
    
    # Failed and out of retries
    return "final_answer"

# %% [markdown]
# ##  Node 5 – final answer node

# %%
# -----------------------------
# Node 5 – final answer node
# -----------------------------

def final_answer_node(state: AgentState):
    out = state["execution_output"]

    if out["returncode"] != 0:
        answer = f"""❌ Failed after {state['retry_count']} retries.

Last Error:
{out['stderr']}

All errors encountered:
{chr(10).join(f"{i+1}. {err[:100]}..." for i, err in enumerate(state["error_history"]))}
"""
    else:
        answer = f"""✅ Animation generated successfully after {state['retry_count']} retries!

Video: {state['video_path']}

Errors fixed: {len(state['error_history'])}
"""

    return {
        **state,
        "final_answer": answer
    }

# %%
graph = StateGraph(AgentState)

# Add all nodes
graph.add_node("prompt_expander", prompt_expander_node)
graph.add_node("code_generator", code_generator_node)
graph.add_node("code_fixer", code_fixer_node)
graph.add_node("code_runner", code_runner_node)
graph.add_node("final_answer", final_answer_node)

# Set entry point
graph.set_entry_point("prompt_expander")

# Initial generation flow
graph.add_edge("prompt_expander", "code_generator")
graph.add_edge("code_generator", "code_runner")

# Conditional: retry or finish
graph.add_conditional_edges(
    "code_runner",
    should_retry,
    {
        "code_fixer": "code_fixer",
        "final_answer": "final_answer"
    }
)

# Fix and retry
graph.add_edge("code_fixer", "code_runner")

# End
graph.add_edge("final_answer", END)
app = graph.compile(debug=True)

# %%
state = {
    "user_query": "What is Logistic Regression and how to Reduce Loss , use manim_voiceover for explanation and keep the explantion in detail upto 60 seconds",
    "generated_code": "",
    "scene_name" : "NewtonScene",
    "execution_output": {},
    "final_answer": "",
    "video_path": "",
    "retry_count": 0,
    "max_retries": 3,
    "error_history": []
}

state
# Out:
# {'user_query': 'What is Logistic Regression and how to Reduce Loss , use manim_voiceover for explanation and keep the explantion in detail upto 60 seconds',
#  'generated_code': '',
#  'scene_name': 'NewtonScene',
#  'execution_output': {},
#  'final_answer': '',
#  'video_path': '',
#  'retry_count': 0,
#  'max_retries': 3,
#  'error_history': []}

# %%
reponse = app.invoke(state)
# Out:
# [values] {'user_query': 'What is Logistic Regression and how to Reduce Loss , use manim_voiceover for explanation and keep the explantion in detail upto 60 seconds', 'generated_code': '', 'scene_name': 'NewtonScene', 'execution_output': {}, 'final_answer': '', 'video_path': '', 'retry_count': 0, 'max_retries': 3, 'error_history': []}
# [updates] {'prompt_expander': {'user_query': 'OBJECTS: \n- Text("Logistic Regression and Loss Reduction", font_size=40, color=WHITE) for the title.\n- Axes(x_range=(-4,4), y_range=(-1,1), axis_config={"color": BLUE}) for plotting the sigmoid function and loss curve.\n- Graph(x_range=(-4,4), y_range=(-1,1), color=RED) for the sigmoid curve.\n- Text("Logistic Regression: A model for binary classification using a sigmoid function.", font_size=28, color=DARK_BROWN) for definition.\n- Text("The sigmoid function: σ(z) = 1 / (1 + e^(-z))", font_size=28, color=GREEN) for the equation.\n- Text("Log Loss (Binary Cross-Entropy): -[y_true * log(y_pred) + (1-y_true) * log(1-y_pred)]", font_size=28, color=PINK) for loss function.\n- Text("Gradient Descent: Iteratively updates weights to minimize loss.", font_size=28, color=ORANGE) for explanation of gradient descent.\n- Arrows (Vector) for visualizing updates, color=BLUE.\n\nPOSITIONS: \n- Move the title to_edge(UP).\n- Position the axes at (0, -2) and then adjust to fit within boundaries.\n- Use next_to() for text and graphs relative to axes.\n- Ensure all objects within x=±6.5, y=±3.5.\n\nANIMATION ORDER: \n1. FadeIn the title text with run_time=1.0. Voiceover: "In this scene, we\'ll explore Logistic Regression and how to reduce its loss."\n2. Create a Text object for Logistic Regression definition, then Write it with run_time=1.0. Voiceover: "Logistic Regression is a statistical model used for binary classification, predicting outcomes like yes/no using a sigmoid function."\n3. Add the Axes and Graph, then Transform the Graph to show the sigmoid curve starting from z=-4 to z=4. Run_time=1.0. Voiceover: "The sigmoid function maps any real-valued number to between 0 and 1, making it ideal for probability predictions."\n4. Animate the sigmoid curve: first, scale it in from a point, then FadeIn labels. Run_time=1.0. Voiceover: "For example, a z-score of 0 gives a probability of 0.5, while extreme values approach 0 or 1."\n5. FadeIn the loss function text. Then, create a separate Graph for loss curve, color=PINK. Use Transform to show a decreasing curve. Run_time=1.0. Voiceover: "The loss function, or log loss, measures prediction error; it\'s minimized to improve model accuracy, with lower loss indicating better fit."\n6. Animate gradient descent steps: Start with initial weights, use Vector arrows to show updates, fading out old and in new values. Run_time=1.0 for each step. Voiceover: "To reduce loss, we use gradient descent, an optimization algorithm that calculates gradients and adjusts weights iteratively until loss stabilizes."\n7. Add caption text at y=-3.0 for summary. Run_time=1.0. Voiceover: "In summary, Logistic Regression models binary outcomes, and loss reduction via gradient descent enhances prediction accuracy."\n\nTIMING: \n- Each animation has default run_time=1.0 seconds. \n- self.wait(1.0) after each major step to allow absorption. \n- Total scene duration: approximately 60 seconds with multiple steps. \n\nTEXT: \n- Title: "Logistic Regression and Loss Reduction", font_size=40. \n- Definition text: font_size=28, color=DARK_BROWN. \n- Sigmoid equation: font_size=28, color=GREEN. \n- Loss function: font_size=28, color=PINK. \n- Gradient descent explanation: font_size=28, color=ORANGE. \n- Caption: "Key takeaway", font_size=24, color=BLUE, position at y=-3.0. \n- Voiceover text: Short blocks, max 12 words, e.g., "Logistic Regression uses a sigmoid curve to model probabilities." \n\nCAMERA: \n- 2D scene, no specific 3D angle needed, use default camera. \n\nSCREEN BOUNDARY RULES: \n- All objects within x=±6.5, y=±3.5. \n- Font sizes: title max 40, body text <=28, captions <=24. \n- Text gaps: 0.6-0.8 units vertically. \n- Voiceover matches one visual action per block. \n\nMANIM_VOICEOVER INTEGRATION: \n- Use manim_voiceover to generate audio for each voiceover text block, ensuring it aligns with the corresponding animation. \n- Total voiceover duration: ~40 seconds, fitting wit ...
# [values] {'user_query': 'OBJECTS: \n- Text("Logistic Regression and Loss Reduction", font_size=40, color=WHITE) for the title.\n- Axes(x_range=(-4,4), y_range=(-1,1), axis_config={"color": BLUE}) for plotting the sigmoid function and loss curve.\n- Graph(x_range=(-4,4), y_range=(-1,1), color=RED) for the sigmoid curve.\n- Text("Logistic Regression: A model for binary classification using a sigmoid function.", font_size=28, color=DARK_BROWN) for definition.\n- Text("The sigmoid function: σ(z) = 1 / (1 + e^(-z))", font_size=28, color=GREEN) for the equation.\n- Text("Log Loss (Binary Cross-Entropy): -[y_true * log(y_pred) + (1-y_true) * log(1-y_pred)]", font_size=28, color=PINK) for loss function.\n- Text("Gradient Descent: Iteratively updates weights to minimize loss.", font_size=28, color=ORANGE) for explanation of gradient descent.\n- Arrows (Vector) for visualizing updates, color=BLUE.\n\nPOSITIONS: \n- Move the title to_edge(UP).\n- Position the axes at (0, -2) and then adjust to fit within boundaries.\n- Use next_to() for text and graphs relative to axes.\n- Ensure all objects within x=±6.5, y=±3.5.\n\nANIMATION ORDER: \n1. FadeIn the title text with run_time=1.0. Voiceover: "In this scene, we\'ll explore Logistic Regression and how to reduce its loss."\n2. Create a Text object for Logistic Regression definition, then Write it with run_time=1.0. Voiceover: "Logistic Regression is a statistical model used for binary classification, predicting outcomes like yes/no using a sigmoid function."\n3. Add the Axes and Graph, then Transform the Graph to show the sigmoid curve starting from z=-4 to z=4. Run_time=1.0. Voiceover: "The sigmoid function maps any real-valued number to between 0 and 1, making it ideal for probability predictions."\n4. Animate the sigmoid curve: first, scale it in from a point, then FadeIn labels. Run_time=1.0. Voiceover: "For example, a z-score of 0 gives a probability of 0.5, while extreme values approach 0 or 1."\n5. FadeIn the loss function text. Then, create a separate Graph for loss curve, color=PINK. Use Transform to show a decreasing curve. Run_time=1.0. Voiceover: "The loss function, or log loss, measures prediction error; it\'s minimized to improve model accuracy, with lower loss indicating better fit."\n6. Animate gradient descent steps: Start with initial weights, use Vector arrows to show updates, fading out old and in new values. Run_time=1.0 for each step. Voiceover: "To reduce loss, we use gradient descent, an optimization algorithm that calculates gradients and adjusts weights iteratively until loss stabilizes."\n7. Add caption text at y=-3.0 for summary. Run_time=1.0. Voiceover: "In summary, Logistic Regression models binary outcomes, and loss reduction via gradient descent enhances prediction accuracy."\n\nTIMING: \n- Each animation has default run_time=1.0 seconds. \n- self.wait(1.0) after each major step to allow absorption. \n- Total scene duration: approximately 60 seconds with multiple steps. \n\nTEXT: \n- Title: "Logistic Regression and Loss Reduction", font_size=40. \n- Definition text: font_size=28, color=DARK_BROWN. \n- Sigmoid equation: font_size=28, color=GREEN. \n- Loss function: font_size=28, color=PINK. \n- Gradient descent explanation: font_size=28, color=ORANGE. \n- Caption: "Key takeaway", font_size=24, color=BLUE, position at y=-3.0. \n- Voiceover text: Short blocks, max 12 words, e.g., "Logistic Regression uses a sigmoid curve to model probabilities." \n\nCAMERA: \n- 2D scene, no specific 3D angle needed, use default camera. \n\nSCREEN BOUNDARY RULES: \n- All objects within x=±6.5, y=±3.5. \n- Font sizes: title max 40, body text <=28, captions <=24. \n- Text gaps: 0.6-0.8 units vertically. \n- Voiceover matches one visual action per block. \n\nMANIM_VOICEOVER INTEGRATION: \n- Use manim_voiceover to generate audio for each voiceover text block, ensuring it aligns with the corresponding animation. \n- Total voiceover duration: ~40 seconds, fitting within 60-second scene.  ...
# [updates] {'code_generator': {'user_query': 'OBJECTS: \n- Text("Logistic Regression and Loss Reduction", font_size=40, color=WHITE) for the title.\n- Axes(x_range=(-4,4), y_range=(-1,1), axis_config={"color": BLUE}) for plotting the sigmoid function and loss curve.\n- Graph(x_range=(-4,4), y_range=(-1,1), color=RED) for the sigmoid curve.\n- Text("Logistic Regression: A model for binary classification using a sigmoid function.", font_size=28, color=DARK_BROWN) for definition.\n- Text("The sigmoid function: σ(z) = 1 / (1 + e^(-z))", font_size=28, color=GREEN) for the equation.\n- Text("Log Loss (Binary Cross-Entropy): -[y_true * log(y_pred) + (1-y_true) * log(1-y_pred)]", font_size=28, color=PINK) for loss function.\n- Text("Gradient Descent: Iteratively updates weights to minimize loss.", font_size=28, color=ORANGE) for explanation of gradient descent.\n- Arrows (Vector) for visualizing updates, color=BLUE.\n\nPOSITIONS: \n- Move the title to_edge(UP).\n- Position the axes at (0, -2) and then adjust to fit within boundaries.\n- Use next_to() for text and graphs relative to axes.\n- Ensure all objects within x=±6.5, y=±3.5.\n\nANIMATION ORDER: \n1. FadeIn the title text with run_time=1.0. Voiceover: "In this scene, we\'ll explore Logistic Regression and how to reduce its loss."\n2. Create a Text object for Logistic Regression definition, then Write it with run_time=1.0. Voiceover: "Logistic Regression is a statistical model used for binary classification, predicting outcomes like yes/no using a sigmoid function."\n3. Add the Axes and Graph, then Transform the Graph to show the sigmoid curve starting from z=-4 to z=4. Run_time=1.0. Voiceover: "The sigmoid function maps any real-valued number to between 0 and 1, making it ideal for probability predictions."\n4. Animate the sigmoid curve: first, scale it in from a point, then FadeIn labels. Run_time=1.0. Voiceover: "For example, a z-score of 0 gives a probability of 0.5, while extreme values approach 0 or 1."\n5. FadeIn the loss function text. Then, create a separate Graph for loss curve, color=PINK. Use Transform to show a decreasing curve. Run_time=1.0. Voiceover: "The loss function, or log loss, measures prediction error; it\'s minimized to improve model accuracy, with lower loss indicating better fit."\n6. Animate gradient descent steps: Start with initial weights, use Vector arrows to show updates, fading out old and in new values. Run_time=1.0 for each step. Voiceover: "To reduce loss, we use gradient descent, an optimization algorithm that calculates gradients and adjusts weights iteratively until loss stabilizes."\n7. Add caption text at y=-3.0 for summary. Run_time=1.0. Voiceover: "In summary, Logistic Regression models binary outcomes, and loss reduction via gradient descent enhances prediction accuracy."\n\nTIMING: \n- Each animation has default run_time=1.0 seconds. \n- self.wait(1.0) after each major step to allow absorption. \n- Total scene duration: approximately 60 seconds with multiple steps. \n\nTEXT: \n- Title: "Logistic Regression and Loss Reduction", font_size=40. \n- Definition text: font_size=28, color=DARK_BROWN. \n- Sigmoid equation: font_size=28, color=GREEN. \n- Loss function: font_size=28, color=PINK. \n- Gradient descent explanation: font_size=28, color=ORANGE. \n- Caption: "Key takeaway", font_size=24, color=BLUE, position at y=-3.0. \n- Voiceover text: Short blocks, max 12 words, e.g., "Logistic Regression uses a sigmoid curve to model probabilities." \n\nCAMERA: \n- 2D scene, no specific 3D angle needed, use default camera. \n\nSCREEN BOUNDARY RULES: \n- All objects within x=±6.5, y=±3.5. \n- Font sizes: title max 40, body text <=28, captions <=24. \n- Text gaps: 0.6-0.8 units vertically. \n- Voiceover matches one visual action per block. \n\nMANIM_VOICEOVER INTEGRATION: \n- Use manim_voiceover to generate audio for each voiceover text block, ensuring it aligns with the corresponding animation. \n- Total voiceover duration: ~40 seconds, fitting with ...
# [values] {'user_query': 'OBJECTS: \n- Text("Logistic Regression and Loss Reduction", font_size=40, color=WHITE) for the title.\n- Axes(x_range=(-4,4), y_range=(-1,1), axis_config={"color": BLUE}) for plotting the sigmoid function and loss curve.\n- Graph(x_range=(-4,4), y_range=(-1,1), color=RED) for the sigmoid curve.\n- Text("Logistic Regression: A model for binary classification using a sigmoid function.", font_size=28, color=DARK_BROWN) for definition.\n- Text("The sigmoid function: σ(z) = 1 / (1 + e^(-z))", font_size=28, color=GREEN) for the equation.\n- Text("Log Loss (Binary Cross-Entropy): -[y_true * log(y_pred) + (1-y_true) * log(1-y_pred)]", font_size=28, color=PINK) for loss function.\n- Text("Gradient Descent: Iteratively updates weights to minimize loss.", font_size=28, color=ORANGE) for explanation of gradient descent.\n- Arrows (Vector) for visualizing updates, color=BLUE.\n\nPOSITIONS: \n- Move the title to_edge(UP).\n- Position the axes at (0, -2) and then adjust to fit within boundaries.\n- Use next_to() for text and graphs relative to axes.\n- Ensure all objects within x=±6.5, y=±3.5.\n\nANIMATION ORDER: \n1. FadeIn the title text with run_time=1.0. Voiceover: "In this scene, we\'ll explore Logistic Regression and how to reduce its loss."\n2. Create a Text object for Logistic Regression definition, then Write it with run_time=1.0. Voiceover: "Logistic Regression is a statistical model used for binary classification, predicting outcomes like yes/no using a sigmoid function."\n3. Add the Axes and Graph, then Transform the Graph to show the sigmoid curve starting from z=-4 to z=4. Run_time=1.0. Voiceover: "The sigmoid function maps any real-valued number to between 0 and 1, making it ideal for probability predictions."\n4. Animate the sigmoid curve: first, scale it in from a point, then FadeIn labels. Run_time=1.0. Voiceover: "For example, a z-score of 0 gives a probability of 0.5, while extreme values approach 0 or 1."\n5. FadeIn the loss function text. Then, create a separate Graph for loss curve, color=PINK. Use Transform to show a decreasing curve. Run_time=1.0. Voiceover: "The loss function, or log loss, measures prediction error; it\'s minimized to improve model accuracy, with lower loss indicating better fit."\n6. Animate gradient descent steps: Start with initial weights, use Vector arrows to show updates, fading out old and in new values. Run_time=1.0 for each step. Voiceover: "To reduce loss, we use gradient descent, an optimization algorithm that calculates gradients and adjusts weights iteratively until loss stabilizes."\n7. Add caption text at y=-3.0 for summary. Run_time=1.0. Voiceover: "In summary, Logistic Regression models binary outcomes, and loss reduction via gradient descent enhances prediction accuracy."\n\nTIMING: \n- Each animation has default run_time=1.0 seconds. \n- self.wait(1.0) after each major step to allow absorption. \n- Total scene duration: approximately 60 seconds with multiple steps. \n\nTEXT: \n- Title: "Logistic Regression and Loss Reduction", font_size=40. \n- Definition text: font_size=28, color=DARK_BROWN. \n- Sigmoid equation: font_size=28, color=GREEN. \n- Loss function: font_size=28, color=PINK. \n- Gradient descent explanation: font_size=28, color=ORANGE. \n- Caption: "Key takeaway", font_size=24, color=BLUE, position at y=-3.0. \n- Voiceover text: Short blocks, max 12 words, e.g., "Logistic Regression uses a sigmoid curve to model probabilities." \n\nCAMERA: \n- 2D scene, no specific 3D angle needed, use default camera. \n\nSCREEN BOUNDARY RULES: \n- All objects within x=±6.5, y=±3.5. \n- Font sizes: title max 40, body text <=28, captions <=24. \n- Text gaps: 0.6-0.8 units vertically. \n- Voiceover matches one visual action per block. \n\nMANIM_VOICEOVER INTEGRATION: \n- Use manim_voiceover to generate audio for each voiceover text block, ensuring it aligns with the corresponding animation. \n- Total voiceover duration: ~40 seconds, fitting within 60-second scene.  ...
# [updates] {'code_runner': {'user_query': 'OBJECTS: \n- Text("Logistic Regression and Loss Reduction", font_size=40, color=WHITE) for the title.\n- Axes(x_range=(-4,4), y_range=(-1,1), axis_config={"color": BLUE}) for plotting the sigmoid function and loss curve.\n- Graph(x_range=(-4,4), y_range=(-1,1), color=RED) for the sigmoid curve.\n- Text("Logistic Regression: A model for binary classification using a sigmoid function.", font_size=28, color=DARK_BROWN) for definition.\n- Text("The sigmoid function: σ(z) = 1 / (1 + e^(-z))", font_size=28, color=GREEN) for the equation.\n- Text("Log Loss (Binary Cross-Entropy): -[y_true * log(y_pred) + (1-y_true) * log(1-y_pred)]", font_size=28, color=PINK) for loss function.\n- Text("Gradient Descent: Iteratively updates weights to minimize loss.", font_size=28, color=ORANGE) for explanation of gradient descent.\n- Arrows (Vector) for visualizing updates, color=BLUE.\n\nPOSITIONS: \n- Move the title to_edge(UP).\n- Position the axes at (0, -2) and then adjust to fit within boundaries.\n- Use next_to() for text and graphs relative to axes.\n- Ensure all objects within x=±6.5, y=±3.5.\n\nANIMATION ORDER: \n1. FadeIn the title text with run_time=1.0. Voiceover: "In this scene, we\'ll explore Logistic Regression and how to reduce its loss."\n2. Create a Text object for Logistic Regression definition, then Write it with run_time=1.0. Voiceover: "Logistic Regression is a statistical model used for binary classification, predicting outcomes like yes/no using a sigmoid function."\n3. Add the Axes and Graph, then Transform the Graph to show the sigmoid curve starting from z=-4 to z=4. Run_time=1.0. Voiceover: "The sigmoid function maps any real-valued number to between 0 and 1, making it ideal for probability predictions."\n4. Animate the sigmoid curve: first, scale it in from a point, then FadeIn labels. Run_time=1.0. Voiceover: "For example, a z-score of 0 gives a probability of 0.5, while extreme values approach 0 or 1."\n5. FadeIn the loss function text. Then, create a separate Graph for loss curve, color=PINK. Use Transform to show a decreasing curve. Run_time=1.0. Voiceover: "The loss function, or log loss, measures prediction error; it\'s minimized to improve model accuracy, with lower loss indicating better fit."\n6. Animate gradient descent steps: Start with initial weights, use Vector arrows to show updates, fading out old and in new values. Run_time=1.0 for each step. Voiceover: "To reduce loss, we use gradient descent, an optimization algorithm that calculates gradients and adjusts weights iteratively until loss stabilizes."\n7. Add caption text at y=-3.0 for summary. Run_time=1.0. Voiceover: "In summary, Logistic Regression models binary outcomes, and loss reduction via gradient descent enhances prediction accuracy."\n\nTIMING: \n- Each animation has default run_time=1.0 seconds. \n- self.wait(1.0) after each major step to allow absorption. \n- Total scene duration: approximately 60 seconds with multiple steps. \n\nTEXT: \n- Title: "Logistic Regression and Loss Reduction", font_size=40. \n- Definition text: font_size=28, color=DARK_BROWN. \n- Sigmoid equation: font_size=28, color=GREEN. \n- Loss function: font_size=28, color=PINK. \n- Gradient descent explanation: font_size=28, color=ORANGE. \n- Caption: "Key takeaway", font_size=24, color=BLUE, position at y=-3.0. \n- Voiceover text: Short blocks, max 12 words, e.g., "Logistic Regression uses a sigmoid curve to model probabilities." \n\nCAMERA: \n- 2D scene, no specific 3D angle needed, use default camera. \n\nSCREEN BOUNDARY RULES: \n- All objects within x=±6.5, y=±3.5. \n- Font sizes: title max 40, body text <=28, captions <=24. \n- Text gaps: 0.6-0.8 units vertically. \n- Voiceover matches one visual action per block. \n\nMANIM_VOICEOVER INTEGRATION: \n- Use manim_voiceover to generate audio for each voiceover text block, ensuring it aligns with the corresponding animation. \n- Total voiceover duration: ~40 seconds, fitting within  ...
# [values] {'user_query': 'OBJECTS: \n- Text("Logistic Regression and Loss Reduction", font_size=40, color=WHITE) for the title.\n- Axes(x_range=(-4,4), y_range=(-1,1), axis_config={"color": BLUE}) for plotting the sigmoid function and loss curve.\n- Graph(x_range=(-4,4), y_range=(-1,1), color=RED) for the sigmoid curve.\n- Text("Logistic Regression: A model for binary classification using a sigmoid function.", font_size=28, color=DARK_BROWN) for definition.\n- Text("The sigmoid function: σ(z) = 1 / (1 + e^(-z))", font_size=28, color=GREEN) for the equation.\n- Text("Log Loss (Binary Cross-Entropy): -[y_true * log(y_pred) + (1-y_true) * log(1-y_pred)]", font_size=28, color=PINK) for loss function.\n- Text("Gradient Descent: Iteratively updates weights to minimize loss.", font_size=28, color=ORANGE) for explanation of gradient descent.\n- Arrows (Vector) for visualizing updates, color=BLUE.\n\nPOSITIONS: \n- Move the title to_edge(UP).\n- Position the axes at (0, -2) and then adjust to fit within boundaries.\n- Use next_to() for text and graphs relative to axes.\n- Ensure all objects within x=±6.5, y=±3.5.\n\nANIMATION ORDER: \n1. FadeIn the title text with run_time=1.0. Voiceover: "In this scene, we\'ll explore Logistic Regression and how to reduce its loss."\n2. Create a Text object for Logistic Regression definition, then Write it with run_time=1.0. Voiceover: "Logistic Regression is a statistical model used for binary classification, predicting outcomes like yes/no using a sigmoid function."\n3. Add the Axes and Graph, then Transform the Graph to show the sigmoid curve starting from z=-4 to z=4. Run_time=1.0. Voiceover: "The sigmoid function maps any real-valued number to between 0 and 1, making it ideal for probability predictions."\n4. Animate the sigmoid curve: first, scale it in from a point, then FadeIn labels. Run_time=1.0. Voiceover: "For example, a z-score of 0 gives a probability of 0.5, while extreme values approach 0 or 1."\n5. FadeIn the loss function text. Then, create a separate Graph for loss curve, color=PINK. Use Transform to show a decreasing curve. Run_time=1.0. Voiceover: "The loss function, or log loss, measures prediction error; it\'s minimized to improve model accuracy, with lower loss indicating better fit."\n6. Animate gradient descent steps: Start with initial weights, use Vector arrows to show updates, fading out old and in new values. Run_time=1.0 for each step. Voiceover: "To reduce loss, we use gradient descent, an optimization algorithm that calculates gradients and adjusts weights iteratively until loss stabilizes."\n7. Add caption text at y=-3.0 for summary. Run_time=1.0. Voiceover: "In summary, Logistic Regression models binary outcomes, and loss reduction via gradient descent enhances prediction accuracy."\n\nTIMING: \n- Each animation has default run_time=1.0 seconds. \n- self.wait(1.0) after each major step to allow absorption. \n- Total scene duration: approximately 60 seconds with multiple steps. \n\nTEXT: \n- Title: "Logistic Regression and Loss Reduction", font_size=40. \n- Definition text: font_size=28, color=DARK_BROWN. \n- Sigmoid equation: font_size=28, color=GREEN. \n- Loss function: font_size=28, color=PINK. \n- Gradient descent explanation: font_size=28, color=ORANGE. \n- Caption: "Key takeaway", font_size=24, color=BLUE, position at y=-3.0. \n- Voiceover text: Short blocks, max 12 words, e.g., "Logistic Regression uses a sigmoid curve to model probabilities." \n\nCAMERA: \n- 2D scene, no specific 3D angle needed, use default camera. \n\nSCREEN BOUNDARY RULES: \n- All objects within x=±6.5, y=±3.5. \n- Font sizes: title max 40, body text <=28, captions <=24. \n- Text gaps: 0.6-0.8 units vertically. \n- Voiceover matches one visual action per block. \n\nMANIM_VOICEOVER INTEGRATION: \n- Use manim_voiceover to generate audio for each voiceover text block, ensuring it aligns with the corresponding animation. \n- Total voiceover duration: ~40 seconds, fitting within 60-second scene.  ...
# [updates] {'final_answer': {'user_query': 'OBJECTS: \n- Text("Logistic Regression and Loss Reduction", font_size=40, color=WHITE) for the title.\n- Axes(x_range=(-4,4), y_range=(-1,1), axis_config={"color": BLUE}) for plotting the sigmoid function and loss curve.\n- Graph(x_range=(-4,4), y_range=(-1,1), color=RED) for the sigmoid curve.\n- Text("Logistic Regression: A model for binary classification using a sigmoid function.", font_size=28, color=DARK_BROWN) for definition.\n- Text("The sigmoid function: σ(z) = 1 / (1 + e^(-z))", font_size=28, color=GREEN) for the equation.\n- Text("Log Loss (Binary Cross-Entropy): -[y_true * log(y_pred) + (1-y_true) * log(1-y_pred)]", font_size=28, color=PINK) for loss function.\n- Text("Gradient Descent: Iteratively updates weights to minimize loss.", font_size=28, color=ORANGE) for explanation of gradient descent.\n- Arrows (Vector) for visualizing updates, color=BLUE.\n\nPOSITIONS: \n- Move the title to_edge(UP).\n- Position the axes at (0, -2) and then adjust to fit within boundaries.\n- Use next_to() for text and graphs relative to axes.\n- Ensure all objects within x=±6.5, y=±3.5.\n\nANIMATION ORDER: \n1. FadeIn the title text with run_time=1.0. Voiceover: "In this scene, we\'ll explore Logistic Regression and how to reduce its loss."\n2. Create a Text object for Logistic Regression definition, then Write it with run_time=1.0. Voiceover: "Logistic Regression is a statistical model used for binary classification, predicting outcomes like yes/no using a sigmoid function."\n3. Add the Axes and Graph, then Transform the Graph to show the sigmoid curve starting from z=-4 to z=4. Run_time=1.0. Voiceover: "The sigmoid function maps any real-valued number to between 0 and 1, making it ideal for probability predictions."\n4. Animate the sigmoid curve: first, scale it in from a point, then FadeIn labels. Run_time=1.0. Voiceover: "For example, a z-score of 0 gives a probability of 0.5, while extreme values approach 0 or 1."\n5. FadeIn the loss function text. Then, create a separate Graph for loss curve, color=PINK. Use Transform to show a decreasing curve. Run_time=1.0. Voiceover: "The loss function, or log loss, measures prediction error; it\'s minimized to improve model accuracy, with lower loss indicating better fit."\n6. Animate gradient descent steps: Start with initial weights, use Vector arrows to show updates, fading out old and in new values. Run_time=1.0 for each step. Voiceover: "To reduce loss, we use gradient descent, an optimization algorithm that calculates gradients and adjusts weights iteratively until loss stabilizes."\n7. Add caption text at y=-3.0 for summary. Run_time=1.0. Voiceover: "In summary, Logistic Regression models binary outcomes, and loss reduction via gradient descent enhances prediction accuracy."\n\nTIMING: \n- Each animation has default run_time=1.0 seconds. \n- self.wait(1.0) after each major step to allow absorption. \n- Total scene duration: approximately 60 seconds with multiple steps. \n\nTEXT: \n- Title: "Logistic Regression and Loss Reduction", font_size=40. \n- Definition text: font_size=28, color=DARK_BROWN. \n- Sigmoid equation: font_size=28, color=GREEN. \n- Loss function: font_size=28, color=PINK. \n- Gradient descent explanation: font_size=28, color=ORANGE. \n- Caption: "Key takeaway", font_size=24, color=BLUE, position at y=-3.0. \n- Voiceover text: Short blocks, max 12 words, e.g., "Logistic Regression uses a sigmoid curve to model probabilities." \n\nCAMERA: \n- 2D scene, no specific 3D angle needed, use default camera. \n\nSCREEN BOUNDARY RULES: \n- All objects within x=±6.5, y=±3.5. \n- Font sizes: title max 40, body text <=28, captions <=24. \n- Text gaps: 0.6-0.8 units vertically. \n- Voiceover matches one visual action per block. \n\nMANIM_VOICEOVER INTEGRATION: \n- Use manim_voiceover to generate audio for each voiceover text block, ensuring it aligns with the corresponding animation. \n- Total voiceover duration: ~40 seconds, fitting within ...
# [values] {'user_query': 'OBJECTS: \n- Text("Logistic Regression and Loss Reduction", font_size=40, color=WHITE) for the title.\n- Axes(x_range=(-4,4), y_range=(-1,1), axis_config={"color": BLUE}) for plotting the sigmoid function and loss curve.\n- Graph(x_range=(-4,4), y_range=(-1,1), color=RED) for the sigmoid curve.\n- Text("Logistic Regression: A model for binary classification using a sigmoid function.", font_size=28, color=DARK_BROWN) for definition.\n- Text("The sigmoid function: σ(z) = 1 / (1 + e^(-z))", font_size=28, color=GREEN) for the equation.\n- Text("Log Loss (Binary Cross-Entropy): -[y_true * log(y_pred) + (1-y_true) * log(1-y_pred)]", font_size=28, color=PINK) for loss function.\n- Text("Gradient Descent: Iteratively updates weights to minimize loss.", font_size=28, color=ORANGE) for explanation of gradient descent.\n- Arrows (Vector) for visualizing updates, color=BLUE.\n\nPOSITIONS: \n- Move the title to_edge(UP).\n- Position the axes at (0, -2) and then adjust to fit within boundaries.\n- Use next_to() for text and graphs relative to axes.\n- Ensure all objects within x=±6.5, y=±3.5.\n\nANIMATION ORDER: \n1. FadeIn the title text with run_time=1.0. Voiceover: "In this scene, we\'ll explore Logistic Regression and how to reduce its loss."\n2. Create a Text object for Logistic Regression definition, then Write it with run_time=1.0. Voiceover: "Logistic Regression is a statistical model used for binary classification, predicting outcomes like yes/no using a sigmoid function."\n3. Add the Axes and Graph, then Transform the Graph to show the sigmoid curve starting from z=-4 to z=4. Run_time=1.0. Voiceover: "The sigmoid function maps any real-valued number to between 0 and 1, making it ideal for probability predictions."\n4. Animate the sigmoid curve: first, scale it in from a point, then FadeIn labels. Run_time=1.0. Voiceover: "For example, a z-score of 0 gives a probability of 0.5, while extreme values approach 0 or 1."\n5. FadeIn the loss function text. Then, create a separate Graph for loss curve, color=PINK. Use Transform to show a decreasing curve. Run_time=1.0. Voiceover: "The loss function, or log loss, measures prediction error; it\'s minimized to improve model accuracy, with lower loss indicating better fit."\n6. Animate gradient descent steps: Start with initial weights, use Vector arrows to show updates, fading out old and in new values. Run_time=1.0 for each step. Voiceover: "To reduce loss, we use gradient descent, an optimization algorithm that calculates gradients and adjusts weights iteratively until loss stabilizes."\n7. Add caption text at y=-3.0 for summary. Run_time=1.0. Voiceover: "In summary, Logistic Regression models binary outcomes, and loss reduction via gradient descent enhances prediction accuracy."\n\nTIMING: \n- Each animation has default run_time=1.0 seconds. \n- self.wait(1.0) after each major step to allow absorption. \n- Total scene duration: approximately 60 seconds with multiple steps. \n\nTEXT: \n- Title: "Logistic Regression and Loss Reduction", font_size=40. \n- Definition text: font_size=28, color=DARK_BROWN. \n- Sigmoid equation: font_size=28, color=GREEN. \n- Loss function: font_size=28, color=PINK. \n- Gradient descent explanation: font_size=28, color=ORANGE. \n- Caption: "Key takeaway", font_size=24, color=BLUE, position at y=-3.0. \n- Voiceover text: Short blocks, max 12 words, e.g., "Logistic Regression uses a sigmoid curve to model probabilities." \n\nCAMERA: \n- 2D scene, no specific 3D angle needed, use default camera. \n\nSCREEN BOUNDARY RULES: \n- All objects within x=±6.5, y=±3.5. \n- Font sizes: title max 40, body text <=28, captions <=24. \n- Text gaps: 0.6-0.8 units vertically. \n- Voiceover matches one visual action per block. \n\nMANIM_VOICEOVER INTEGRATION: \n- Use manim_voiceover to generate audio for each voiceover text block, ensuring it aligns with the corresponding animation. \n- Total voiceover duration: ~40 seconds, fitting within 60-second scene.  ...

# %%
reponse
# Out:
# {'user_query': 'OBJECTS: \n- Text("Logistic Regression and Loss Reduction", font_size=40, color=WHITE) for the title.\n- Axes(x_range=(-4,4), y_range=(-1,1), axis_config={"color": BLUE}) for plotting the sigmoid function and loss curve.\n- Graph(x_range=(-4,4), y_range=(-1,1), color=RED) for the sigmoid curve.\n- Text("Logistic Regression: A model for binary classification using a sigmoid function.", font_size=28, color=DARK_BROWN) for definition.\n- Text("The sigmoid function: σ(z) = 1 / (1 + e^(-z))", font_size=28, color=GREEN) for the equation.\n- Text("Log Loss (Binary Cross-Entropy): -[y_true * log(y_pred) + (1-y_true) * log(1-y_pred)]", font_size=28, color=PINK) for loss function.\n- Text("Gradient Descent: Iteratively updates weights to minimize loss.", font_size=28, color=ORANGE) for explanation of gradient descent.\n- Arrows (Vector) for visualizing updates, color=BLUE.\n\nPOSITIONS: \n- Move the title to_edge(UP).\n- Position the axes at (0, -2) and then adjust to fit within boundaries.\n- Use next_to() for text and graphs relative to axes.\n- Ensure all objects within x=±6.5, y=±3.5.\n\nANIMATION ORDER: \n1. FadeIn the title text with run_time=1.0. Voiceover: "In this scene, we\'ll explore Logistic Regression and how to reduce its loss."\n2. Create a Text object for Logistic Regression definition, then Write it with run_time=1.0. Voiceover: "Logistic Regression is a statistical model used for binary classification, predicting outcomes like yes/no using a sigmoid function."\n3. Add the Axes and Graph, then Transform the Graph to show the sigmoid curve starting from z=-4 to z=4. Run_time=1.0. Voiceover: "The sigmoid function maps any real-valued number to between 0 and 1, making it ideal for probability predictions."\n4. Animate the sigmoid curve: first, scale it in from a point, then FadeIn labels. Run_time=1.0. Voiceover: "For example, a z-score of 0 gives a probability of 0.5, while extreme values approach 0 or 1."\n5. FadeIn the loss function text. Then, create a separate Graph for loss curve, color=PINK. Use Transform to show a decreasing curve. Run_time=1.0. Voiceover: "The loss function, or log loss, measures prediction error; it\'s minimized to improve model accuracy, with lower loss indicating better fit."\n6. Animate gradient descent steps: Start with initial weights, use Vector arrows to show updates, fading out old and in new values. Run_time=1.0 for each step. Voiceover: "To reduce loss, we use gradient descent, an optimization algorithm that calculates gradients and adjusts weights iteratively until loss stabilizes."\n7. Add caption text at y=-3.0 for summary. Run_time=1.0. Voiceover: "In summary, Logistic Regression models binary outcomes, and loss reduction via gradient descent enhances prediction accuracy."\n\nTIMING: \n- Each animation has default run_time=1.0 seconds. \n- self.wait(1.0) after each major step to allow absorption. \n- Total scene duration: approximately 60 seconds with multiple steps. \n\nTEXT: \n- Title: "Logistic Regression and Loss Reduction", font_size=40. \n- Definition text: font_size=28, color=DARK_BROWN. \n- Sigmoid equation: font_size=28, color=GREEN. \n- Loss function: font_size=28, color=PINK. \n- Gradient descent explanation: font_size=28, color=ORANGE. \n- Caption: "Key takeaway", font_size=24, color=BLUE, position at y=-3.0. \n- Voiceover text: Short blocks, max 12 words, e.g., "Logistic Regression uses a sigmoid curve to model probabilities." \n\nCAMERA: \n- 2D scene, no specific 3D angle needed, use default camera. \n\nSCREEN BOUNDARY RULES: \n- All objects within x=±6.5, y=±3.5. \n- Font sizes: title max 40, body text <=28, captions <=24. \n- Text gaps: 0.6-0.8 units vertically. \n- Voiceover matches one visual action per block. \n\nMANIM_VOICEOVER INTEGRATION: \n- Use manim_voiceover to generate audio for each voiceover text block, ensuring it aligns with the corresponding animation. \n- Total voiceover duration: ~40 seconds, fitting within 60-second scene. \n\nCOLOR ...
#  'generated_code': 'from manim import *\nfrom manim_voiceover import VoiceoverScene\nfrom manim_voiceover.services.gtts import GTTSService\nimport numpy as np\n\nclass NewtonScene(VoiceoverScene):\n    def construct(self):\n        self.set_speech_service(GTTSService())\n\n        # 1. Title\n        title_text = Text("Logistic Regression and Loss Reduction", font_size=40, color=WHITE)\n        title_text.to_edge(UP)\n        with self.voiceover(text="In this scene, we\'ll explore Logistic Regression and how to reduce its loss.") as tracker:\n            self.play(FadeIn(title_text, run_time=tracker.duration))\n        self.wait(1)\n\n        # 2. Logistic Regression Definition\n        logistic_def_text = Text(\n            "Logistic Regression: A model for binary classification using a sigmoid function.",\n            font_size=28, color=DARK_BROWN,\n            line_spacing=1.5\n        ).next_to(title_text, DOWN, buff=0.8)\n        # Ensure text is within y boundaries\n        if logistic_def_text.get_y() + logistic_def_text.height/2 > 3.5:\n             logistic_def_text.to_edge(UP, buff=0.5)\n        if logistic_def_text.get_y() - logistic_def_text.height/2 < -3.5:\n            logistic_def_text.to_edge(DOWN, buff=0.5)\n\n        with self.voiceover(text="Logistic Regression: a model for binary classification, predicting outcomes using a sigmoid function.") as tracker:\n            self.play(Write(logistic_def_text, run_time=tracker.duration))\n        self.wait(1)\n\n        # Sigmoid function\n        def sigmoid(z):\n            return 1 / (1 + np.exp(-z))\n\n        # 3. Axes and Sigmoid Curve\n        axes = Axes(\n            x_range=[-4, 4, 1],\n            y_range=[0, 1, 0.5], \n            x_length=7, \n            y_length=3, \n            axis_config={"color": BLUE, "include_numbers": True},\n        )\n        axes.move_to(DOWN * 2) # Position at (0, -2)\n        # Ensure axes are within x=±6.5, y=±3.5\n        if axes.get_x() + axes.width/2 > 6.5: axes.to_edge(RIGHT, buff=0.5)\n        if axes.get_x() - axes.width/2 < -6.5: axes.to_edge(LEFT, buff=0.5)\n        if axes.get_y() + axes.height/2 > 3.5: axes.to_edge(UP, buff=0.5)\n        if axes.get_y() - axes.height/2 < -3.5: axes.to_edge(DOWN, buff=0.5)\n\n        sigmoid_curve = axes.plot(sigmoid, color=RED)\n        \n        with self.voiceover(text="The sigmoid function maps any real number to between 0 and 1, ideal for probability predictions.") as tracker:\n            self.play(Create(axes), Create(sigmoid_curve), run_time=tracker.duration)\n        self.wait(1)\n\n        # 4. Animate sigmoid curve and labels\n        sigmoid_equation_text = MathTex(\n            r"\\sigma(z) = \\frac{1}{1 + e^{-z}}",\n            font_size=28, color=GREEN\n        ).next_to(axes, UP, buff=0.5)\n        \n        with self.voiceover(text="A z-score of 0 yields 0.5 probability; extreme values approach 0 or 1.") as tracker:\n            self.play(FadeIn(sigmoid_equation_text), run_time=tracker.duration)\n        self.wait(1)\n\n        # 5. Loss Function\n        loss_function_text = MathTex(\n            r"\\text{Log Loss: } -[y_{\\text{true}} \\cdot \\log(y_{\\text{pred}}) + (1-y_{\\text{true}}) \\cdot \\log(1-y_{\\text{pred}})]",\n            font_size=28, color=PINK\n        ).next_to(sigmoid_equation_text, UP, buff=0.6)\n        # Ensure text is within y boundaries\n        if loss_function_text.get_y() + loss_function_text.height/2 > 3.5:\n             loss_function_text.to_edge(UP, buff=0.5)\n        if loss_function_text.get_y() - loss_function_text.height/2 < -3.5:\n            loss_function_text.to_edge(DOWN, buff=0.5)\n\n        with self.voiceover(text="Log loss measures prediction error. Minimizing it improves model accuracy, lower loss means better fit.") as tracker:\n            self.play(FadeIn(loss_function_text), run_time=tracker.duration)\n        self.wait(1)\n\n        # Transition to loss curve visualization\n        self.play(\n            FadeOut ...
#  'scene_name': 'NewtonScene',
#  'execution_output': {'stdout': "Manim Community v0.19.2\n\n[02/17/26 10:47:40] INFO     Automatically converted   scene_file_writer.py:383\n                             media\\voiceovers\\in-this-                         \n                             scene-we-ll-explore-logis                         \n                             tic-regression-6801dd66.m                         \n                             p3 to .wav                                        \n[02/17/26 10:47:41] INFO     Animation 0 : Partial     scene_file_writer.py:590\n                             movie file written in                             \n                             'C:\\Users\\prana\\Desktop\\V                         \n                             S_CODE\\Langraph\\manim_age                         \n                             nt\\media\\videos\\NewtonSce                         \n                             ne\\480p15\\partial_movie_f                         \n                             iles\\NewtonScene\\15847952                         \n                             14_1587094897_223132457.m                         \n                             p4'                                               \n[02/17/26 10:47:42] INFO     Animation 1 : Partial     scene_file_writer.py:590\n                             movie file written in                             \n                             'C:\\Users\\prana\\Desktop\\V                         \n                             S_CODE\\Langraph\\manim_age                         \n                             nt\\media\\videos\\NewtonSce                         \n                             ne\\480p15\\partial_movie_f                         \n                             iles\\NewtonScene\\40728202                         \n                             71_4217992463_3604942365.                         \n                             mp4'                                              \n[02/17/26 10:47:43] INFO     Automatically converted   scene_file_writer.py:383\n                             media\\voiceovers\\logistic                         \n                             -regression-a-model-for-b                         \n                             inary-e0bbaa84.mp3 to                             \n                             .wav                                              \n[02/17/26 10:47:45] INFO     Animation 2 : Partial     scene_file_writer.py:590\n                             movie file written in                             \n                             'C:\\Users\\prana\\Desktop\\V                         \n                             S_CODE\\Langraph\\manim_age                         \n                             nt\\media\\videos\\NewtonSce                         \n                             ne\\480p15\\partial_movie_f                         \n                             iles\\NewtonScene\\40728202                         \n                             71_863907582_1335450719.m                         \n                             p4'                                               \n                    INFO     Animation 3 : Partial     scene_file_writer.py:590\n                             movie file written in                             \n                             'C:\\Users\\prana\\Desktop\\V                         \n                             S_CODE\\Langraph\\manim_age                         \n                             nt\\media\\videos\\NewtonSce                         \n                             ne\\480p15\\partial_movie_f                         \n                             iles\\NewtonScene\\40728202                         \n                             71_4217992463_2780556455.                         \n                             mp4'                                              \n                    INFO     Writing 0 to               tex_file_writing.py:111\n                             media\\Tex\\66e1bc57a83e0f07                     ...
#   'stderr': "c:\\Users\\prana\\Desktop\\VS_CODE\\Langraph\\myvenv\\Lib\\site-packages\\manim_voiceover\\__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.\n  import pkg_resources\n<frozen runpy>:128: RuntimeWarning: 'manim.__main__' found in sys.modules after import of package 'manim', but prior to execution of 'manim.__main__'; this may result in unpredictable behaviour\n\nAnimation 0: FadeIn(Text('Logistic Regression and Loss Reduction')):   0%|          | 0/91 [00:00<?, ?it/s]\nAnimation 0: FadeIn(Text('Logistic Regression and Loss Reduction')):  13%|#3        | 12/91 [00:00<00:00, 111.14it/s]\nAnimation 0: FadeIn(Text('Logistic Regression and Loss Reduction')):  26%|##6       | 24/91 [00:00<00:00, 115.06it/s]\nAnimation 0: FadeIn(Text('Logistic Regression and Loss Reduction')):  41%|####      | 37/91 [00:00<00:00, 120.77it/s]\nAnimation 0: FadeIn(Text('Logistic Regression and Loss Reduction')):  55%|#####4    | 50/91 [00:00<00:00, 121.82it/s]\nAnimation 0: FadeIn(Text('Logistic Regression and Loss Reduction')):  69%|######9   | 63/91 [00:00<00:00, 123.24it/s]\nAnimation 0: FadeIn(Text('Logistic Regression and Loss Reduction')):  84%|########3 | 76/91 [00:00<00:00, 122.19it/s]\nAnimation 0: FadeIn(Text('Logistic Regression and Loss Reduction')):  98%|#########7| 89/91 [00:00<00:00, 118.68it/s]\n                                                                                                                     \n\nAnimation 2: Write(Text('Logistic Regression: A model for binary classification using a sigmoid function.')):   0%|          | 0/126 [00:00<?, ?it/s]\nAnimation 2: Write(Text('Logistic Regression: A model for binary classification using a sigmoid function.')):  12%|#1        | 15/126 [00:00<00:00, 143.15it/s]\nAnimation 2: Write(Text('Logistic Regression: A model for binary classification using a sigmoid function.')):  24%|##3       | 30/126 [00:00<00:00, 134.38it/s]\nAnimation 2: Write(Text('Logistic Regression: A model for binary classification using a sigmoid function.')):  35%|###4      | 44/126 [00:00<00:00, 122.89it/s]\nAnimation 2: Write(Text('Logistic Regression: A model for binary classification using a sigmoid function.')):  45%|####5     | 57/126 [00:00<00:00, 112.99it/s]\nAnimation 2: Write(Text('Logistic Regression: A model for binary classification using a sigmoid function.')):  55%|#####4    | 69/126 [00:00<00:00, 103.01it/s]\nAnimation 2: Write(Text('Logistic Regression: A model for binary classification using a sigmoid function.')):  63%|######3   | 80/126 [00:00<00:00, 96.79it/s] \nAnimation 2: Write(Text('Logistic Regression: A model for binary classification using a sigmoid function.')):  71%|#######1  | 90/126 [00:00<00:00, 91.18it/s]\nAnimation 2: Write(Text('Logistic Regression: A model for binary classification using a sigmoid function.')):  79%|#######9  | 100/126 [00:01<00:00, 84.53it/s]\nAnimation 2: Write(Text('Logistic Regression: A model for binary classification using a sigmoid function.')):  87%|########6 | 109/126 [00:01<00:00, 80.91it/s]\nAnimation 2: Write(Text('Logistic Regression: A model for binary classification using a sigmoid function.')):  94%|#########3| 118/126 [00:01<00:00, 79.40it/s]\nAnimation 2: Write(Text('Logistic Regression: A model for binary classification using a sigmoid function.')): 100%|##########| 126/126 [00:01<00:00, 78.72it/s]\n                                                                                                                                                               \nlatex: major issue: So far, you have not checked for MiKTeX updates.\nlatex: major issue: So far, you have not checked for MiKTeX updates.\nlatex: major issue: So far, you have not checked for MiKTeX updates.\n\nAnimation 4: Create(Axes of 2 submobjects), etc.:   0%|      ...
#   'returncode': 0,
#   'video_path': 'media\\videos\\NewtonScene\\480p15\\NewtonScene.mp4'},
#  'final_answer': '✅ Animation generated successfully after 0 retries!\n\nVideo: media\\videos\\NewtonScene\\480p15\\NewtonScene.mp4\n\nErrors fixed: 0\n',
#  'video_path': 'media\\videos\\NewtonScene\\480p15\\NewtonScene.mp4',
#  'retry_count': 0,
#  'max_retries': 3,
#  'error_history': []}

# %% [markdown]
# # Debug

# %%
state = {
    "user_query": "Explain how Sigmoid function Works and how it is linked with Logistic Regression, include voice explanation ",
    "generated_code": "",
    "scene_name" : "NewtonScene",
    "execution_output": {},
    "final_answer": "",
    "video_path": "",
    "retry_count": 0,
    "max_retries": 3,
    "error_history": []
}

state
# Out:
# {'user_query': 'Explain how Sigmoid function Works and how it is linked with Logistic Regression, include voice explanation ',
#  'generated_code': '',
#  'scene_name': 'NewtonScene',
#  'execution_output': {},
#  'final_answer': '',
#  'video_path': '',
#  'retry_count': 0,
#  'max_retries': 3,
#  'error_history': []}

# %%
state = prompt_expander_node(state)

print("Query")
print(state["user_query"])
# Out:
# Query
# Create a title text positioned at y=+3.0 with font_size=40, color=YELLOW, text="Sigmoid Function and Logistic Regression". Then, fade_in the title with run_time=1.0. Next, create a set of Axes centered at the origin with x_range from -6 to 6, y_range from 0 to 1, color=DARK_GRAY, and label the axes with text "x" and "y". Then, play the animation to draw the Sigmoid function curve, defined as f(x) = 1 / (1 + e^{-x}), using a BLUE color, with run_time=1.0. After that, add a text label below the graph to explain the Sigmoid function, such as "The Sigmoid function maps any real-valued number to a value between 0 and 1, often used in machine learning for binary classification.", positioned at y=-2.0 with font_size=28, color=WHITE. Then, fade in this explanation text with run_time=0.5. Next, introduce the link to Logistic Regression by showing a simple decision boundary. Create a scatter plot with 4 data points: two red points at (-4, 0.2) and (4, 0.8) representing different classes, and two green points at (-2, 0.6) and (2, 0.4). Use a VGroup for these points with colors RED and GREEN. Then, transform the Sigmoid curve to act as the decision boundary in a 2D plot. Use a Transform animation from the Sigmoid curve to the decision boundary line, but since it's a curve, keep it as the Sigmoid shape. Add a text explanation: "Logistic Regression uses the Sigmoid function to model the probability of a binary outcome, fitting the curve to data points.", positioned at y=0 with font_size=28, color=BLACK. Then, write this text with run_time=1.0. After that, add a caption at y=-3.0 with font_size=24, text="Key takeaway: Sigmoid enables Logistic Regression to output probabilities.", and fade it in with run_time=0.5. Finally, fade out all text except the main explanation, and end with a static graph. Self.wait(1.0) between major steps to allow for pauses. Total scene length should be around 45 seconds. Ensure all Mobjects stay within x=-6.5 to 6.5 and y=-3.5 to 3.5 boundaries. Use built-in Mobjects like Axes, Graph, Text, and VGroup. For the Sigmoid curve, use a plot created with GraphScene or direct plotting. Animation order: 1. Title fade in. 2. Axes creation. 3. Sigmoid curve creation. 4. Explanation text. 5. Decision boundary points. 6. Link text. 7. Caption. 8. Fade out. Voiceover can be implied with text descriptions for each step.

# %%
state = code_generator_node(state)

print("Generated Code:\n")
print(state["generated_code"])
# Out:
# Generated Code:
#
# from manim import *
# import numpy as np
#
# class NewtonScene(Scene):
#     def construct(self):
#         # 1. Title fade in
#         title = Text("Sigmoid Function and Logistic Regression", font_size=40, color=YELLOW)
#         title.move_to(UP * 3.0)
#         self.play(FadeIn(title, run_time=1.0))
#         self.wait(1.0)
#
#         # 2. Axes creation
#         axes = Axes(
#             x_range=[-6, 6, 1],
#             y_range=[0, 1, 0.2],
#             x_length=12,
#             y_length=4,
#             axis_config={"color": DARK_GREY},
#         )
#         axes.move_to(ORIGIN)
#         x_label = axes.get_x_axis().get_axis_label("x")
#         y_label = axes.get_y_axis().get_axis_label("y", edge=LEFT, direction=UP)
#         axes_labels = VGroup(x_label, y_label)
#         self.play(Create(axes), Create(axes_labels))
#         self.wait(1.0)
#
#         # 3. Sigmoid curve creation
#         def sigmoid_function(x):
#             return 1 / (1 + np.exp(-x))
#
#         sigmoid_curve = axes.plot(sigmoid_function, color=BLUE)
#         self.play(Create(sigmoid_curve, run_time=1.0))
#         self.wait(1.0)
#
#         # 4. Explanation text
#         sigmoid_explanation = Text(
#             "The Sigmoid function maps any real-valued number to a value between 0 and 1, often used in machine learning for binary classification.",
#             font_size=28,
#             color=WHITE,
#             line_spacing=1.5
#         )
#         sigmoid_explanation.move_to(DOWN * 2.0)
#         self.play(FadeIn(sigmoid_explanation, run_time=0.5))
#         self.wait(1.0)
#
#         # 5. Decision boundary points
#         red_points = VGroup(
#             Dot(axes.coords_to_point(-4, 0.2), color=RED),
#             Dot(axes.coords_to_point(4, 0.8), color=RED)
#         )
#         green_points = VGroup(
#             Dot(axes.coords_to_point(-2, 0.6), color=GREEN),
#             Dot(axes.coords_to_point(2, 0.4), color=GREEN)
#         )
#         data_points_group = VGroup(red_points, green_points)
#         self.play(Create(data_points_group))
#         self.wait(1.0)
#
#         # 6. Link text (Logistic Regression explanation)
#         logistic_explanation = Text(
#             "Logistic Regression uses the Sigmoid function to model the probability of a binary outcome, fitting the curve to data points.",
#             font_size=28,
#             color=BLACK,
#             line_spacing=1.5
#         )
#         logistic_explanation.move_to(ORIGIN)
#         self.play(Write(logistic_explanation, run_time=1.0))
#         self.wait(1.0)
#
#         # 7. Caption
#         caption = Text("Key takeaway: Sigmoid enables Logistic Regression to output probabilities.", font_size=24, color=WHITE)
#         caption.move_to(DOWN * 3.0)
#         self.play(FadeIn(caption, run_time=0.5))
#         self.wait(1.0)
#
#         # 8. Fade out specific text and end with static graph
#         self.play(
#             FadeOut(title),
#             FadeOut(logistic_explanation),
#             FadeOut(caption)
#         )
#         self.wait(1.0)

# %%
state = code_runner_node(state)

state
# Out:
# {'user_query': 'Create a title text positioned at y=+3.0 with font_size=40, color=YELLOW, text="Sigmoid Function and Logistic Regression". Then, fade_in the title with run_time=1.0. Next, create a set of Axes centered at the origin with x_range from -6 to 6, y_range from 0 to 1, color=DARK_GRAY, and label the axes with text "x" and "y". Then, play the animation to draw the Sigmoid function curve, defined as f(x) = 1 / (1 + e^{-x}), using a BLUE color, with run_time=1.0. After that, add a text label below the graph to explain the Sigmoid function, such as "The Sigmoid function maps any real-valued number to a value between 0 and 1, often used in machine learning for binary classification.", positioned at y=-2.0 with font_size=28, color=WHITE. Then, fade in this explanation text with run_time=0.5. Next, introduce the link to Logistic Regression by showing a simple decision boundary. Create a scatter plot with 4 data points: two red points at (-4, 0.2) and (4, 0.8) representing different classes, and two green points at (-2, 0.6) and (2, 0.4). Use a VGroup for these points with colors RED and GREEN. Then, transform the Sigmoid curve to act as the decision boundary in a 2D plot. Use a Transform animation from the Sigmoid curve to the decision boundary line, but since it\'s a curve, keep it as the Sigmoid shape. Add a text explanation: "Logistic Regression uses the Sigmoid function to model the probability of a binary outcome, fitting the curve to data points.", positioned at y=0 with font_size=28, color=BLACK. Then, write this text with run_time=1.0. After that, add a caption at y=-3.0 with font_size=24, text="Key takeaway: Sigmoid enables Logistic Regression to output probabilities.", and fade it in with run_time=0.5. Finally, fade out all text except the main explanation, and end with a static graph. Self.wait(1.0) between major steps to allow for pauses. Total scene length should be around 45 seconds. Ensure all Mobjects stay within x=-6.5 to 6.5 and y=-3.5 to 3.5 boundaries. Use built-in Mobjects like Axes, Graph, Text, and VGroup. For the Sigmoid curve, use a plot created with GraphScene or direct plotting. Animation order: 1. Title fade in. 2. Axes creation. 3. Sigmoid curve creation. 4. Explanation text. 5. Decision boundary points. 6. Link text. 7. Caption. 8. Fade out. Voiceover can be implied with text descriptions for each step.',
#  'generated_code': 'from manim import *\nimport numpy as np\n\nclass NewtonScene(Scene):\n    def construct(self):\n        # 1. Title fade in\n        title = Text("Sigmoid Function and Logistic Regression", font_size=40, color=YELLOW)\n        title.move_to(UP * 3.0)\n        self.play(FadeIn(title, run_time=1.0))\n        self.wait(1.0);\n\n        # 2. Axes creation\n        axes = Axes(\n            x_range=[-6, 6, 1],\n            y_range=[0, 1, 0.2],\n            x_length=12,\n            y_length=4,\n            axis_config={"color": DARK_GREY},\n        )\n        axes.move_to(ORIGIN)\n\n        # Fix: Manually create and position axis labels to avoid TypeError with get_axis_label\n        x_label = Text("x", font_size=24, color=WHITE)\n        x_label.next_to(axes.get_x_axis(), DOWN, buff=SMALL_BUFF)\n\n        y_label = Text("y", font_size=24, color=WHITE)\n        y_label.next_to(axes.get_y_axis(), LEFT, buff=SMALL_BUFF)\n        y_label.align_to(axes.get_y_axis(), UP) # Align top of label with top of y-axis\n\n        axes_labels = VGroup(x_label, y_label)\n        self.play(Create(axes), Create(axes_labels))\n        self.wait(1.0);\n\n        # 3. Sigmoid curve creation\n        def sigmoid_function(x):\n            return 1 / (1 + np.exp(-x))\n\n        sigmoid_curve = axes.plot(sigmoid_function, color=BLUE)\n        self.play(Create(sigmoid_curve, run_time=1.0))\n        self.wait(1.0);\n\n        # 4. Explanation text\n        sigmoid_explanation = Text(\n            "The Sigmoid function maps any real-valued number to a value between 0 and 1, often used in machine learning for binary classification.",\n            font_size=28, \n            color=WHITE,\n            line_spacing=1.5\n        )\n        sigmoid_explanation.move_to(DOWN * 2.0)\n        self.play(FadeIn(sigmoid_explanation, run_time=0.5))\n        self.wait(1.0);\n\n        # 5. Decision boundary points\n        red_points = VGroup(\n            Dot(axes.coords_to_point(-4, 0.2), color=RED),\n            Dot(axes.coords_to_point(4, 0.8), color=RED)\n        )\n        green_points = VGroup(\n            Dot(axes.coords_to_point(-2, 0.6), color=GREEN),\n            Dot(axes.coords_to_point(2, 0.4), color=GREEN)\n        )\n        data_points_group = VGroup(red_points, green_points)\n        self.play(Create(data_points_group))\n        self.wait(1.0);\n\n        # 6. Link text (Logistic Regression explanation)\n        logistic_explanation = Text(\n            "Logistic Regression uses the Sigmoid function to model the probability of a binary outcome, fitting the curve to data points.",\n            font_size=28, \n            color=WHITE, # Changed from BLACK to WHITE for visibility on a dark background\n            line_spacing=1.5\n        )\n        logistic_explanation.move_to(ORIGIN)\n        self.play(Write(logistic_explanation, run_time=1.0))\n        self.wait(1.0);\n\n        # 7. Caption\n        caption = Text("Key takeaway: Sigmoid enables Logistic Regression to output probabilities.", font_size=24, color=WHITE)\n        caption.move_to(DOWN * 3.0)\n        self.play(FadeIn(caption, run_time=0.5))\n        self.wait(1.0);\n\n        # 8. Fade out specific text and end with static graph\n        self.play(\n            FadeOut(title),\n            FadeOut(logistic_explanation),\n            FadeOut(caption)\n        )\n        self.wait(1.0);',
#  'scene_name': 'NewtonScene',
#  'execution_output': {'stdout': "Manim Community v0.19.2\n\n[02/17/26 10:42:02] INFO     Animation 0 : Using cached    cairo_renderer.py:94\n                             data (hash :                                      \n                             1584795214_2046831337_2231324                     \n                             57)                                               \n[02/17/26 10:42:03] INFO     Animation 1 : Using cached    cairo_renderer.py:94\n                             data (hash :                                      \n                             4072820271_2834709167_3622348                     \n                             489)                                              \n                    INFO     Animation 2 : Partial     scene_file_writer.py:590\n                             movie file written in                             \n                             'C:\\Users\\prana\\Desktop\\V                         \n                             S_CODE\\Langraph\\manim_age                         \n                             nt\\media\\videos\\NewtonSce                         \n                             ne\\480p15\\partial_movie_f                         \n                             iles\\NewtonScene\\40728202                         \n                             71_1480776314_3205778658.                         \n                             mp4'                                              \n[02/17/26 10:42:04] INFO     Animation 3 : Partial     scene_file_writer.py:590\n                             movie file written in                             \n                             'C:\\Users\\prana\\Desktop\\V                         \n                             S_CODE\\Langraph\\manim_age                         \n                             nt\\media\\videos\\NewtonSce                         \n                             ne\\480p15\\partial_movie_f                         \n                             iles\\NewtonScene\\40728202                         \n                             71_2834709167_3257024354.                         \n                             mp4'                                              \n                    INFO     Animation 4 : Partial     scene_file_writer.py:590\n                             movie file written in                             \n                             'C:\\Users\\prana\\Desktop\\V                         \n                             S_CODE\\Langraph\\manim_age                         \n                             nt\\media\\videos\\NewtonSce                         \n                             ne\\480p15\\partial_movie_f                         \n                             iles\\NewtonScene\\40728202                         \n                             71_4117533095_1882581623.                         \n                             mp4'                                              \n                    INFO     Animation 5 : Partial     scene_file_writer.py:590\n                             movie file written in                             \n                             'C:\\Users\\prana\\Desktop\\V                         \n                             S_CODE\\Langraph\\manim_age                         \n                             nt\\media\\videos\\NewtonSce                         \n                             ne\\480p15\\partial_movie_f                         \n                             iles\\NewtonScene\\40728202                         \n                             71_2834709167_1196039289.                         \n                             mp4'                                              \n[02/17/26 10:42:05] INFO     Animation 6 : Partial     scene_file_writer.py:590\n                             movie file written in                             \n                             'C:\\Users\\prana\\Desktop\\V                         \n                             S_CODE\\Langraph\\manim_age                      ...
#   'stderr': "c:\\Users\\prana\\Desktop\\VS_CODE\\Langraph\\myvenv\\Lib\\site-packages\\manim_voiceover\\__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.\n  import pkg_resources\n<frozen runpy>:128: RuntimeWarning: 'manim.__main__' found in sys.modules after import of package 'manim', but prior to execution of 'manim.__main__'; this may result in unpredictable behaviour\n\nAnimation 0: FadeIn(Text('Sigmoid Function and Logistic Regression')):   0%|          | 0/1 [00:00<?, ?it/s]\n                                                                                                            \n\nAnimation 2: Create(Axes of 2 submobjects), etc.:   0%|          | 0/15 [00:00<?, ?it/s]\n                                                                                        \n\nAnimation 4: Create(ParametricFunction):   0%|          | 0/15 [00:00<?, ?it/s]\n                                                                               \n\nAnimation 6: FadeIn(Text('The Sigmoid function maps any real-valued number to a value between 0 and 1, often used in machine learning for binary classification.')):   0%|          | 0/8 [00:00<?, ?it/s]\nAnimation 6: FadeIn(Text('The Sigmoid function maps any real-valued number to a value between 0 and 1, often used in machine learning for binary classification.')):  75%|#######5  | 6/8 [00:00<00:00, 53.54it/s]\n                                                                                                                                                                                                                  \n\nAnimation 8: Create(VGroup of 2 submobjects):   0%|          | 0/15 [00:00<?, ?it/s]\n                                                                                    \n\nAnimation 10: Write(Text('Logistic Regression uses the Sigmoid function to model the probability of a binary outcome, fitting the curve to data points.')):   0%|          | 0/15 [00:00<?, ?it/s]\nAnimation 10: Write(Text('Logistic Regression uses the Sigmoid function to model the probability of a binary outcome, fitting the curve to data points.')):  60%|######    | 9/15 [00:00<00:00, 80.32it/s]\n                                                                                                                                                                                                          \n\nAnimation 12: FadeIn(Text('Key takeaway: Sigmoid enables Logistic Regression to output probabilities.')):   0%|          | 0/8 [00:00<?, ?it/s]\n                                                                                                                                               \n\nAnimation 14: FadeOut(Text('Sigmoid Function and Logistic Regression')), etc.:   0%|          | 0/15 [00:00<?, ?it/s]\nAnimation 14: FadeOut(Text('Sigmoid Function and Logistic Regression')), etc.:  20%|##        | 3/15 [00:00<00:00, 20.79it/s]\nAnimation 14: FadeOut(Text('Sigmoid Function and Logistic Regression')), etc.:  40%|####      | 6/15 [00:00<00:00, 20.67it/s]\nAnimation 14: FadeOut(Text('Sigmoid Function and Logistic Regression')), etc.:  60%|######    | 9/15 [00:00<00:00, 20.73it/s]\nAnimation 14: FadeOut(Text('Sigmoid Function and Logistic Regression')), etc.:  80%|########  | 12/15 [00:00<00:00, 20.49it/s]\nAnimation 14: FadeOut(Text('Sigmoid Function and Logistic Regression')), etc.: 100%|##########| 15/15 [00:00<00:00, 20.42it/s]\n                                                                                                                              \n",
#   'returncode': 0,
#   'video_path': 'media\\videos\\NewtonScene\\480p15\\NewtonScene.mp4'},
#  'final_answer': '',
#  'video_path': 'media\\videos\\NewtonScene\\480p15\\NewtonScene.mp4',
#  'retry_count': 1,
#  'max_retries': 3,
#  'error_history': ['c:\\Users\\prana\\Desktop\\VS_CODE\\Langraph\\myvenv\\Lib\\site-packages\\manim_voiceover\\__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.\n  import pkg_resources\n<frozen runpy>:128: RuntimeWarning: \'manim.__main__\' found in sys.modules after import of package \'manim\', but prior to execution of \'manim.__main__\'; this may result in unpredictable behaviour\n\nAnimation 0: FadeIn(Text(\'Sigmoid Function and Logistic Regression\')):   0%|          | 0/15 [00:00<?, ?it/s]\nAnimation 0: FadeIn(Text(\'Sigmoid Function and Logistic Regression\')):  73%|#######3  | 11/15 [00:00<00:00, 103.28it/s]\n                                                                                                                       \n┌───────────────────── Traceback (most recent call last) ─────────────────────┐\n│ c:\\Users\\prana\\Desktop\\VS_CODE\\Langraph\\myvenv\\Lib\\site-packages\\manim\\cli\\ │\n│ render\\commands.py:125 in render                                            │\n│                                                                             │\n│   122 │   │   │   try:                                                      │\n│   123 │   │   │   │   with tempconfig({}):                                  │\n│   124 │   │   │   │   │   scene = SceneClass()                              │\n│ > 125 │   │   │   │   │   scene.render()                                    │\n│   126 │   │   │   except Exception:                                         │\n│   127 │   │   │   │   error_console.print_exception()                       │\n│   128 │   │   │   │   sys.exit(1)                                           │\n│                                                                             │\n│ c:\\Users\\prana\\Desktop\\VS_CODE\\Langraph\\myvenv\\Lib\\site-packages\\manim\\scen │\n│ e\\scene.py:259 in render                                                    │\n│                                                                             │\n│    256 │   │   """                                                          │\n│    257 │   │   self.setup()                                                 │\n│    258 │   │   try:                                                         │\n│ >  259 │   │   │   self.construct()                                         │\n│    260 │   │   except EndSceneEarlyException:                               │\n│    261 │   │   │   pass                                                     │\n│    262 │   │   except RerunSceneException:                                  │\n│                                                                             │\n│ c:\\Users\\prana\\Desktop\\VS_CODE\\Langraph\\manim_agent\\tmp\\NewtonScene.py:21   │\n│ in construct                                                                │\n│                                                                             │\n│   18 │   │   │   axis_config={"color": DARK_GREY},                          │\n│   19 │   │   )                                                              │\n│   20 │   │   axes.move_to(ORIGIN)                                           │\n│ > 21 │   │   x_label = axes.get_x_axis().get_axis_label("x")                │\n│   22 │   │   y_label = axes.get_y_axis().get_axis_label("y", edge=LEFT, dir │\n│   23 │   │   axes_labels = VGroup(x_label, y_label)                         │\n│   24 │   │   self.play(Create(axes), Create(axes_labels))                   │\n└─────────────────────────────────────────────────────────────────────────────┘\nTypeError: Mobject.__getattr__.<locals>.getter() takes 1 positional argument \nbut 2 were given\n'],
#  'error_fixed': None}

# %%
print(state['execution_output']["stderr"])
# Out:
# c:\Users\prana\Desktop\VS_CODE\Langraph\myvenv\Lib\site-packages\manim_voiceover\__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# <frozen runpy>:128: RuntimeWarning: 'manim.__main__' found in sys.modules after import of package 'manim', but prior to execution of 'manim.__main__'; this may result in unpredictable behaviour
#
# Animation 0: FadeIn(Text('Sigmoid Function and Logistic Regression')):   0%|          | 0/15 [00:00<?, ?it/s]
# Animation 0: FadeIn(Text('Sigmoid Function and Logistic Regression')):  73%|#######3  | 11/15 [00:00<00:00, 103.28it/s]
#
# ┌───────────────────── Traceback (most recent call last) ─────────────────────┐
# │ c:\Users\prana\Desktop\VS_CODE\Langraph\myvenv\Lib\site-packages\manim\cli\ │
# │ render\commands.py:125 in render                                            │
# │                                                                             │
# │   122 │   │   │   try:                                                      │
# │   123 │   │   │   │   with tempconfig({}):                                  │
# │   124 │   │   │   │   │   scene = SceneClass()                              │
# │ > 125 │   │   │   │   │   scene.render()                                    │
# │   126 │   │   │   except Exception:                                         │
# │   127 │   │   │   │   error_console.print_exception()                       │
# │   128 │   │   │   │   sys.exit(1)                                           │
# │                                                                             │
# │ c:\Users\prana\Desktop\VS_CODE\Langraph\myvenv\Lib\site-packages\manim\scen │
# │ e\scene.py:259 in render                                                    │
# │                                                                             │
# │    256 │   │   """                                                          │
# │    257 │   │   self.setup()                                                 │
# │    258 │   │   try:                                                         │
# │ >  259 │   │   │   self.construct()                                         │
# │    260 │   │   except EndSceneEarlyException:                               │
# │    261 │   │   │   pass                                                     │
# │    262 │   │   except RerunSceneException:                                  │
# │                                                                             │
# │ c:\Users\prana\Desktop\VS_CODE\Langraph\manim_agent\tmp\NewtonScene.py:21   │
# │ in construct                                                                │
# │                                                                             │
# │   18 │   │   │   axis_config={"color": DARK_GREY},                          │
# │   19 │   │   )                                                              │
# │   20 │   │   axes.move_to(ORIGIN)                                           │
# │ > 21 │   │   x_label = axes.get_x_axis().get_axis_label("x")                │
# │   22 │   │   y_label = axes.get_y_axis().get_axis_label("y", edge=LEFT, dir │
# │   23 │   │   axes_labels = VGroup(x_label, y_label)                         │
# │   24 │   │   self.play(Create(axes), Create(axes_labels))                   │
# └─────────────────────────────────────────────────────────────────────────────┘
# TypeError: Mobject.__getattr__.<locals>.getter() takes 1 positional argument
# but 2 were given

# %%
decision = should_retry(state)
print("Decision:", decision)
# Out:
# ⚠️  Error detected. Retry 1/3
# Decision: code_fixer

# %%
state = code_fixer_node(state)

print("Retry Count:", state["retry_count"])
print("Fixed Code Preview:\n")
print(state["generated_code"][:500])
# Out:
# Retry Count: 1
# Fixed Code Preview:
#
# from manim import *
# import numpy as np
#
# class NewtonScene(Scene):
#     def construct(self):
#         # 1. Title fade in
#         title = Text("Sigmoid Function and Logistic Regression", font_size=40, color=YELLOW)
#         title.move_to(UP * 3.0)
#         self.play(FadeIn(title, run_time=1.0))
#         self.wait(1.0);
#
#         # 2. Axes creation
#         axes = Axes(
#             x_range=[-6, 6, 1],
#             y_range=[0, 1, 0.2],
#             x_length=12,
#             y_length=4,
#             axis_config

# %%
print(state["generated_code"])
# Out:
# from manim import *
# import numpy as np
#
# class NewtonScene(Scene):
#     def construct(self):
#         # 1. Title fade in
#         title = Text("Sigmoid Function and Logistic Regression", font_size=40, color=YELLOW)
#         title.move_to(UP * 3.0)
#         self.play(FadeIn(title, run_time=1.0))
#         self.wait(1.0);
#
#         # 2. Axes creation
#         axes = Axes(
#             x_range=[-6, 6, 1],
#             y_range=[0, 1, 0.2],
#             x_length=12,
#             y_length=4,
#             axis_config={"color": DARK_GREY},
#         )
#         axes.move_to(ORIGIN)
#
#         # Fix: Manually create and position axis labels to avoid TypeError with get_axis_label
#         x_label = Text("x", font_size=24, color=WHITE)
#         x_label.next_to(axes.get_x_axis(), DOWN, buff=SMALL_BUFF)
#
#         y_label = Text("y", font_size=24, color=WHITE)
#         y_label.next_to(axes.get_y_axis(), LEFT, buff=SMALL_BUFF)
#         y_label.align_to(axes.get_y_axis(), UP) # Align top of label with top of y-axis
#
#         axes_labels = VGroup(x_label, y_label)
#         self.play(Create(axes), Create(axes_labels))
#         self.wait(1.0);
#
#         # 3. Sigmoid curve creation
#         def sigmoid_function(x):
#             return 1 / (1 + np.exp(-x))
#
#         sigmoid_curve = axes.plot(sigmoid_function, color=BLUE)
#         self.play(Create(sigmoid_curve, run_time=1.0))
#         self.wait(1.0);
#
#         # 4. Explanation text
#         sigmoid_explanation = Text(
#             "The Sigmoid function maps any real-valued number to a value between 0 and 1, often used in machine learning for binary classification.",
#             font_size=28,
#             color=WHITE,
#             line_spacing=1.5
#         )
#         sigmoid_explanation.move_to(DOWN * 2.0)
#         self.play(FadeIn(sigmoid_explanation, run_time=0.5))
#         self.wait(1.0);
#
#         # 5. Decision boundary points
#         red_points = VGroup(
#             Dot(axes.coords_to_point(-4, 0.2), color=RED),
#             Dot(axes.coords_to_point(4, 0.8), color=RED)
#         )
#         green_points = VGroup(
#             Dot(axes.coords_to_point(-2, 0.6), color=GREEN),
#             Dot(axes.coords_to_point(2, 0.4), color=GREEN)
#         )
#         data_points_group = VGroup(red_points, green_points)
#         self.play(Create(data_points_group))
#         self.wait(1.0);
#
#         # 6. Link text (Logistic Regression explanation)
#         logistic_explanation = Text(
#             "Logistic Regression uses the Sigmoid function to model the probability of a binary outcome, fitting the curve to data points.",
#             font_size=28,
#             color=WHITE, # Changed from BLACK to WHITE for visibility on a dark background
#             line_spacing=1.5
#         )
#         logistic_explanation.move_to(ORIGIN)
#         self.play(Write(logistic_explanation, run_time=1.0))
#         self.wait(1.0);
#
#         # 7. Caption
#         caption = Text("Key takeaway: Sigmoid enables Logistic Regression to output probabilities.", font_size=24, color=WHITE)
#         caption.move_to(DOWN * 3.0)
#         self.play(FadeIn(caption, run_time=0.5))
#         self.wait(1.0);
#
#         # 8. Fade out specific text and end with static graph
#         self.play(
#             FadeOut(title),
#             FadeOut(logistic_explanation),
#             FadeOut(caption)
#         )
#         self.wait(1.0);

# %%
state = final_answer_node(state)
print(state["final_answer"])
# Out:
# ✅ Animation generated successfully after 1 retries!
#
# Video: media\videos\NewtonScene\480p15\NewtonScene.mp4
#
# Errors fixed: 1

# %%
print(state['error_fixed'])
# Out:
# None
